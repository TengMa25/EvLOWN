# %% [markdown]
# # Robustness test

# %%
# Import useful library

import numpy as np
import pandas as pd
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import matplotlib as mpl
import random
random.seed(71415)

# %% [markdown]
# ## Observational noise $\alpha$
#
# $$y(t) = x(t)+\alpha N(0,1)$$

# %%
# Add observation noise
def add_observation_noise(y,SNR):
    N = len(y)
    noise = np.random.randn(N)
    P_d = np.sum(abs(noise)**2)
    P_signal = np.sum(abs(y)**2)
    P_noise = P_signal/10**(SNR/10.0)
    noise = np.sqrt(P_noise/P_d)*noise
    return noise + y

def simulate_observationnoise(ODE, y0, t, SNR, num_trails):
    response = odeint(ODE, y0 = y0,t = t)
    GroundTruth = response[:,0]
    Observations = np.zeros([len(GroundTruth), num_trails])
    for i in range(num_trails):
        Observations[:,i] = add_observation_noise(GroundTruth, SNR)
    return GroundTruth, Observations

# %% [markdown]
# ## Weakly nonlinear oscillators
#
# 1. Harmonic oscillator
# $$
# \ddot{x} + 0.01 \dot{x}+  10x = 0 \\ \tag{1}
# $$
# 2. Van der pol oscillator
# $$
# \ddot{x} - 0.01 (1-2x^2) \dot{x}+  10x = 0 \\ \tag{2}
# $$
# 3. Duffeling oscillator
# $$
# \ddot{x} + 0.01 (\dot{x}+2x^3) +  10x = 0 \\ \tag{3}
# $$
# 7. Weakly coupled oscillator

# %%
# Governing equations of weakly nonlinear oscillators

def harmonic(x,t):
    dxdt = [x[1], -10*x[0]-0.01*(x[1])]
    return dxdt

def vanderpol(x,t):
    dxdt = [x[1], -10*x[0]-0.01*(2*x[0]**2-1)*x[1]]
    return dxdt

def duffel(x,t):
    dxdt = [x[1], -10*x[0]-0.01*(x[1]+2*x[0]**3)]
    return dxdt

def weaklycoupled(x,t):
    dxdt = [x[1], -10*x[0]-0.01*(x[1]+2*x[0]**3)]
    return dxdt    


ODEs = {"harmonic": harmonic, "vanderpol": vanderpol, "duffel": duffel}
initials = {"harmonic": [5,0], "vanderpol": [0.1,0], "duffel": [5,0]}

# %%
# Basic parameters of simulation

Fs = 100 # sampling frequency 
T = 1000 # simulating time
t = np.linspace(0,T,T*Fs)

# %%
# Ground Truth
for ode in ODEs.keys():
    response = odeint(ODEs[ode], y0 = initials[ode], t = t)
    GT = pd.DataFrame(response[:,0])
    GT.to_csv('./Data/GroundTruth/%s.csv'%ode)

# %% [markdown]
# ## Data samples

# %% [markdown]
# ## Metrics
#
# 1. NED(normalized Euclidean distance)
#
# Normalized Euclidean distance is the metric which can evaluate the discrepancy between true dynamics and predicted dynamic.
# $$
# NED(x,\hat{x}) = \frac{1}{D_{max}(T-t_0)}\sum_{t=t_0}^T \sqrt{(x(t)-\hat{x}(t))^2}
# $$
# where $x,\dot{x}$ is true dynamics and $\hat{x}, \dot{\hat{x}}$ is predicted dynamics; $t_0$ and $T$ are the beginning and ending times, respectively; and $D_{max}$ is the longest Euclidean distance in whole trajectory.
#
# 2. FR(failure ratio)
#
# Failure ratio is the metric which can evaluate the ratio of algorithm discover the governing equations of dynamics correctly. The correct discovery is defined as the non-zero candidate function is same with ground truth or its linear dependent candidate.
#
# $$
# FR = \frac{N_c}{N}
# $$
# where $N_c$ is correct discovery times and $N$ is total simulation times.
#
#
# 3. sMAPE(symmetric mean absolute percentage error)
#
# Symmetric mean absolute percentage error is quantify the discovery inaccuracy.
#
# $$
# sMAPE = \frac{1}{k} \sum_{i=1}^{k} \frac{|D_i-R_i|}{|D_i| + |R_i|}
# $$
# where $k$ is number of candidate functions, $D_i, R_i$ is the discoverd and true coefficients, respectively.

# %%
def NED(GT,PRE):
    D_max = GT.max() - GT.min()
    return np.sum(np.abs(PRE - GT))/D_max

def FR(GT_coefs, PRE_coefs):
    for i in range(len(GT_coefs[0])):
        GT_coef = GT_coefs[:,i]
        if (np.where(GT_coef != 0)[0] == np.where(PRE_coefs != 0)[0]).all():
            return 1
    return 0

def sMAPE(GT_coefs, PRE_coefs):
    diffs = []
    for i in range(len(GT_coefs[0])):
        GT_coef = GT_coefs[:,i]
        mape = np.sum(np.abs(GT_coef - PRE_coefs))/(np.sum(np.abs(GT_coef)) + np.sum(np.abs(PRE_coefs)))/len(GT_coef)
        diffs.append(mape)
    return np.min(diffs)

# %% [markdown]
# ### Linear dependence in evolutionary library
#
# Several candidate functions in library are linear dependent when their coeffienct is weak. Here is an example $x^2\dot{x}$ and $\dot{x}^3$.
#
# Firstly, we derive the contributions of $x^2\dot{x}$ and $\dot{x}^3$ on evolution space by method of average:
#
# $$
# \Phi_A(x^2\dot{x}) =-\frac{1}{2\pi \omega_0}\int_0^{2\pi} \cos(\phi) (x^2\dot{x})d\phi = -\frac{1}{2\pi \omega_0}\int_0^{2\pi} \cos(\phi) (A\sin(\phi))^2 A\omega_0\cos(\phi)d\phi = \frac{0.75 A^3}{2\pi}
# $$
# $$
# \Phi_{\beta}(x^2\dot{x}) =-\frac{1}{2A\pi \omega_0}\int_0^{2\pi} \sin(\phi) (x^2\dot{x})d\phi = -\frac{1}{2A\pi \omega_0}\int_0^{2\pi} \sin(\phi) (A\sin(\phi))^2 A\omega_0\cos(\phi)d\phi = 0
# $$
# $$
# \Phi_A(\dot{x}^3) =-\frac{1}{2\pi \omega_0}\int_0^{2\pi} \cos(\phi) (\dot{x}^3)d\phi = -\frac{1}{2\pi \omega_0}\int_0^{2\pi} \cos(\phi) (A\omega_0\cos(\phi))^3 d\phi = \frac{0.25\omega_0^2 A^3}{2\pi}
# $$
# $$
# \Phi_{\beta}(\dot{x}^3) =-\frac{1}{2A\pi \omega_0}\int_0^{2\pi} \sin(\phi) (\dot{x}^3)d\phi = -\frac{1}{2A\pi \omega_0}\int_0^{2\pi} \sin(\phi) (A\omega_0\cos(\phi))^3d\phi = 0
# $$
#
# It can be clearly seen that candidate $x^2\dot{x}$ and $\dot{x}^3$ are linear dependent, that means $\omega_0^2x^2\dot{x}$ and $3\dot{x}^3$ are totally equivalent for a weakly nonlinear oscillator $\ddot{x}+\epsilon\phi(x,\dot{x})+\omega_0^2x=0$. To prove that, we simulate the weakly nonlinear oscillator with parameter $\epsilon = -1e-2$ and $\omega_0 = 10$.
#
# To weakly nonlinear oscillators, we treat these linear dependent candidates are equivalent. When we validate our results, $\ddot{x}-0.01(3\omega_0^2x^2\dot{x})+\omega_0^2x=0$ and $\ddot{x}-0.01(\dot{x}^3)+\omega_0^2x=0$ are both correct.

# %%
def WND1(x,t):
    dxdt = [x[1], -10*x[0]-0.01*10*3*(x[0]**2*x[1])]
    return dxdt

def WND2(x,t):
    dxdt = [x[1], -10*x[0]-0.01*(x[1]**3)]
    return dxdt


x0_LCO = [1,0]
response1 = odeint(WND1, y0 = x0_LCO,t = t)
response2 = odeint(WND2, y0 = x0_LCO,t = t)
fig,axes = plt.subplots(1,1,figsize = (7,3))
axes.plot(t, response1[:,0], lw = 0.2, alpha = 1, label = "$\ddot{x}-\epsilon(3\omega_0^2x^2\dot{x})+\omega_0^2x=0$")
axes.plot(t, response2[:,0], lw = 0.2, alpha = 0.8, label = "$\ddot{x}-\epsilon(\dot{x}^3)+\omega_0^2x=0$")
axes.plot(t, response1[:,0] - response2[:,0] ,lw = 0.5, label = "Difference")
axes.set_xlim(0,T)
plt.legend()
axes.set_title("Linear dependence in library example")
# Out:
# Text(0.5, 1.0, 'Linear dependence in library example')

# %% [markdown]
# ### Find equivalent form of ground truth
#
# In order to evaluate the algorithm performance appropriately, we need to consider the equivalent form of ground truth. If algorithm discovers the equivalent form from data, it's also accurate governing equation for weakly nonlinear oscillator. The equivalent form

# %%
response = odeint(duffel, y0 = [5,0],t = t)
GroundTruth = response[:,0]
Observation = add_observation_noise(GroundTruth,40)
# Observation2 = add_observation_noise(GroundTruth, 30)
plt.plot(t,Observation)
# plt.plot(t,GroundTruth)

# %%
import sys
sys.path.append("../Model")
import Model
library = [
    lambda x:x[0],
    lambda x:x[0]*x[0],
    lambda x:x[0]*x[0]*x[0],
    lambda x:x[0]*x[0]*x[0]*x[0],
    lambda x:x[0]*x[0]*x[0]*x[0]*x[0],
    lambda x:x[1],
    lambda x:x[1]*x[1],
    lambda x:x[1]*x[1]*x[1],
    lambda x:x[1]*x[1]*x[1]*x[1],
    lambda x:x[1]*x[1]*x[1]*x[1]*x[1],
    lambda x:x[0]*x[1],
    lambda x:x[0]*x[0]*x[1],
    lambda x:x[0]*x[1]*x[1],
    lambda x:x[0]*x[0]*x[0]*x[1],
    lambda x:x[0]*x[0]*x[1]*x[1],
    lambda x:x[0]*x[1]*x[1]*x[1],
    lambda x:x[0]*x[0]*x[0]*x[0]*x[1],
    lambda x:x[0]*x[0]*x[0]*x[1]*x[1],
    lambda x:x[0]*x[0]*x[1]*x[1]*x[1],
    lambda x:x[0]*x[1]*x[1]*x[1]*x[1],
]
library_name = [
    lambda x:x[0],
    lambda x:x[0]+x[0],
    lambda x:x[0]+x[0]+x[0],
    lambda x:x[0]+x[0]+x[0]+x[0],
    lambda x:x[0]+x[0]+x[0]+x[0]+x[0],
    lambda x:x[1],
    lambda x:x[1]+x[1],
    lambda x:x[1]+x[1]+x[1],
    lambda x:x[1]+x[1]+x[1]+x[1],
    lambda x:x[1]+x[1]+x[1]+x[1]+x[1],
    lambda x:x[0]+x[1],
    lambda x:x[0]+x[0]+x[1],
    lambda x:x[0]+x[1]+x[1],
    lambda x:x[0]+x[0]+x[0]+x[1],
    lambda x:x[0]+x[0]+x[1]+x[1],
    lambda x:x[0]+x[1]+x[1]+x[1],
    lambda x:x[0]+x[0]+x[0]+x[0]+x[1],
    lambda x:x[0]+x[0]+x[0]+x[1]+x[1],
    lambda x:x[0]+x[0]+x[1]+x[1]+x[1],
    lambda x:x[0]+x[1]+x[1]+x[1]+x[1],
]
dim = 1
feature_length = len(library)
model = Model.WeakNO(dim,library,library_name)

# %%
# Observation_noise_simulation 100 times
Observation_noises = np.linspace(100,10,10)
save_path = "./Data/Observation_noise/"
num_trail = 100
ODEs = {"duffel": duffel}
initials = {"duffel": [5,0]}

for ode in ODEs.keys():
    print(ode)
    Coef_GT = np.array(pd.read_csv('./Data/GroundTruth/%s_coefficient.csv'%ode,index_col = 0))
    for noise in Observation_noises:
        NEDs = np.zeros(num_trail)
        FRs = np.zeros(num_trail)
        sMAPEs = np.zeros(num_trail)
        Coefs = np.zeros([num_trail, feature_length])
        GT, data = simulate_observationnoise(ODEs[ode], initials[ode], t, noise, num_trail)
        for i in range(num_trail):
            model.Get_frequency(data[:,i].reshape(-1,1),t)
            model.Get_Evolution(smooth_window = 1)
            model.Library_rebuild()
            model.optimize(sparse_threshold = 0.05,
                           stop_tolerance = 1e-4,
                           step_tolerance=  1e-6,
                           w_A2b=1,
                           smooth_window=10)
            Coefs[i,:] = - model.Xi[0]
            Coefs[i,0] = model.Xi[0,0] - model.frequencys[0]**2
            def WND_model(x,t):
                Phi = np.zeros(len(model.library))
                for i in range(len(model.library)):
                    Phi[i] = model.library[i](x)
                dxdt = [x[1], -model.frequencys[0]**2*x[0]-np.sum(Phi*model.Xi[0])]
                return dxdt
            predictions = odeint(WND_model, y0 = initials[ode],t = t)
            # NEDs[i] = NED(GT, predictions[:,0])
            # FRs[i] = FR(Coef_GT, Coefs[i,:])
            # sMAPEs[i] = sMAPE(Coef_GT, Coefs[i,:])
            print("noise %dB, Trails: %d"%(noise, i))
            print(model)
        pd.DataFrame(Coefs).to_csv('./Result/%s_%ddB_coefpredict.csv'%(ode,noise))
        # pd.DataFrame(NEDs).to_csv('./Result/%s_%ddB_NEDs.csv'%(ode,noise))
        # pd.DataFrame(FRs).to_csv('./Result/%s_%ddB_FRs.csv'%(ode,noise))
        # pd.DataFrame(sMAPEs).to_csv('./Result/%s_%ddB_sMAPEs.csv'%(ode,noise))
        # print("noise:%.2f, NED:%.3f, FR: %.3f, sMAPE: %.3f"%(noise, np.mean(NEDs), np.mean(FRs), np.mean(sMAPEs)))
        
        
            
                        

        # import pandas as pd
        # data = pd.DataFrame(data)
        # data.to_csv('%s%s_%ddB.csv'%(save_path, ode, noise))
# Out:
# duffel
# noise 100B, Trails: 0
# x0'' + 9.999281e+00x0 + 9.968396e-03x0' + 6.025767e-03x0x0'x0' = 0
#
# noise 100B, Trails: 1
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968398e-03x0' = 0
#
# noise 100B, Trails: 2
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968401e-03x0' = 0
#
# noise 100B, Trails: 3
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968403e-03x0' = 0
#
# noise 100B, Trails: 4
# x0'' + 9.999281e+00x0 + 9.968398e-03x0' + 6.025761e-03x0x0'x0' = 0
#
# noise 100B, Trails: 5
# x0'' + 9.999281e+00x0 + 9.968400e-03x0' + 6.025765e-03x0x0'x0' = 0
#
# noise 100B, Trails: 6
# x0'' + 9.999281e+00x0 + 2.028848e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 100B, Trails: 7
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968396e-03x0' = 0
#
# noise 100B, Trails: 8
# x0'' + 9.999281e+00x0 + 2.028848e-02x0x0x0 + 9.968401e-03x0' = 0
#
# noise 100B, Trails: 9
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968398e-03x0' = 0
#
# noise 100B, Trails: 10
# x0'' + 9.999281e+00x0 + 2.028849e-02x0x0x0 + 9.968398e-03x0' = 0
#
# noise 100B, Trails: 11
# x0'' + 9.999281e+00x0 + 9.968401e-03x0' + 6.025766e-03x0x0'x0' = 0
#
# noise 100B, Trails: 12
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968402e-03x0' = 0
#
# noise 100B, Trails: 13
# x0'' + 9.999281e+00x0 + 2.028844e-02x0x0x0 + 9.968401e-03x0' = 0
#
# noise 100B, Trails: 14
# x0'' + 9.999281e+00x0 + 2.028845e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 100B, Trails: 15
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 100B, Trails: 16
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968398e-03x0' = 0
#
# noise 100B, Trails: 17
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968402e-03x0' = 0
#
# noise 100B, Trails: 18
# x0'' + 9.999281e+00x0 + 2.028848e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 100B, Trails: 19
# x0'' + 9.999281e+00x0 + 9.968398e-03x0' + 6.025762e-03x0x0'x0' = 0
#
# noise 100B, Trails: 20
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 100B, Trails: 21
# x0'' + 9.999281e+00x0 + 2.028848e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 100B, Trails: 22
# x0'' + 9.999281e+00x0 + 2.028849e-02x0x0x0 + 9.968401e-03x0' = 0
#
# noise 100B, Trails: 23
# x0'' + 9.999281e+00x0 + 2.028845e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 100B, Trails: 24
# x0'' + 9.999281e+00x0 + 9.968401e-03x0' + 6.025768e-03x0x0'x0' = 0
#
# noise 100B, Trails: 25
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 100B, Trails: 26
# x0'' + 9.999281e+00x0 + 9.968405e-03x0' + 6.025774e-03x0x0'x0' = 0
#
# noise 100B, Trails: 27
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968402e-03x0' = 0
#
# noise 100B, Trails: 28
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968398e-03x0' = 0
#
# noise 100B, Trails: 29
# x0'' + 9.999281e+00x0 + 9.968399e-03x0' + 6.025766e-03x0x0'x0' = 0
#
# noise 100B, Trails: 30
# x0'' + 9.999281e+00x0 + 9.968398e-03x0' + 6.025766e-03x0x0'x0' = 0
#
# noise 100B, Trails: 31
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 100B, Trails: 32
# x0'' + 9.999281e+00x0 + 9.968401e-03x0' + 6.025769e-03x0x0'x0' = 0
#
# noise 100B, Trails: 33
# x0'' + 9.999281e+00x0 + 9.968400e-03x0' + 6.025770e-03x0x0'x0' = 0
#
# noise 100B, Trails: 34
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968401e-03x0' = 0
#
# noise 100B, Trails: 35
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968398e-03x0' = 0
#
# noise 100B, Trails: 36
# x0'' + 9.999281e+00x0 + 9.968397e-03x0' + 6.025764e-03x0x0'x0' = 0
#
# noise 100B, Trails: 37
# x0'' + 9.999281e+00x0 + 9.968398e-03x0' + 6.025767e-03x0x0'x0' = 0
#
# noise 100B, Trails: 38
# x0'' + 9.999281e+00x0 + 9.968401e-03x0' + 6.025769e-03x0x0'x0' = 0
#
# noise 100B, Trails: 39
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968401e-03x0' = 0
#
# noise 100B, Trails: 40
# x0'' + 9.999281e+00x0 + 2.028845e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 100B, Trails: 41
# x0'' + 9.999281e+00x0 + 2.028845e-02x0x0x0 + 9.968398e-03x0' = 0
#
# noise 100B, Trails: 42
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968403e-03x0' = 0
#
# noise 100B, Trails: 43
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 100B, Trails: 44
# x0'' + 9.999281e+00x0 + 9.968401e-03x0' + 6.025764e-03x0x0'x0' = 0
#
# noise 100B, Trails: 45
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968402e-03x0' = 0
#
# noise 100B, Trails: 46
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968402e-03x0' = 0
#
# noise 100B, Trails: 47
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 100B, Trails: 48
# x0'' + 9.999281e+00x0 + 2.028848e-02x0x0x0 + 9.968398e-03x0' = 0
#
# noise 100B, Trails: 49
# x0'' + 9.999281e+00x0 + 9.968398e-03x0' + 6.025768e-03x0x0'x0' = 0
#
# noise 100B, Trails: 50
# x0'' + 9.999281e+00x0 + 9.968399e-03x0' + 6.025767e-03x0x0'x0' = 0
#
# noise 100B, Trails: 51
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 100B, Trails: 52
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 100B, Trails: 53
# x0'' + 9.999281e+00x0 + 2.028849e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 100B, Trails: 54
# x0'' + 9.999281e+00x0 + 2.028849e-02x0x0x0 + 9.968401e-03x0' = 0
#
# noise 100B, Trails: 55
# x0'' + 9.999281e+00x0 + 9.968402e-03x0' + 6.025762e-03x0x0'x0' = 0
#
# noise 100B, Trails: 56
# x0'' + 9.999281e+00x0 + 2.028848e-02x0x0x0 + 9.968397e-03x0' = 0
#
# noise 100B, Trails: 57
# x0'' + 9.999281e+00x0 + 2.028849e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 100B, Trails: 58
# x0'' + 9.999281e+00x0 + 9.968400e-03x0' + 6.025768e-03x0x0'x0' = 0
#
# noise 100B, Trails: 59
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 100B, Trails: 60
# x0'' + 9.999281e+00x0 + 9.968403e-03x0' + 6.025765e-03x0x0'x0' = 0
#
# noise 100B, Trails: 61
# x0'' + 9.999281e+00x0 + 2.028845e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 100B, Trails: 62
# x0'' + 9.999281e+00x0 + 9.968398e-03x0' + 6.025762e-03x0x0'x0' = 0
#
# noise 100B, Trails: 63
# x0'' + 9.999281e+00x0 + 2.028848e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 100B, Trails: 64
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968396e-03x0' = 0
#
# noise 100B, Trails: 65
# x0'' + 9.999281e+00x0 + 2.028848e-02x0x0x0 + 9.968401e-03x0' = 0
#
# noise 100B, Trails: 66
# x0'' + 9.999281e+00x0 + 9.968402e-03x0' + 6.025767e-03x0x0'x0' = 0
#
# noise 100B, Trails: 67
# x0'' + 9.999281e+00x0 + 9.968400e-03x0' + 6.025763e-03x0x0'x0' = 0
#
# noise 100B, Trails: 68
# x0'' + 9.999281e+00x0 + 2.028844e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 100B, Trails: 69
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968404e-03x0' = 0
#
# noise 100B, Trails: 70
# x0'' + 9.999281e+00x0 + 2.028849e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 100B, Trails: 71
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 100B, Trails: 72
# x0'' + 9.999281e+00x0 + 9.968402e-03x0' + 6.025770e-03x0x0'x0' = 0
#
# noise 100B, Trails: 73
# x0'' + 9.999281e+00x0 + 9.968402e-03x0' + 6.025766e-03x0x0'x0' = 0
#
# noise 100B, Trails: 74
# x0'' + 9.999281e+00x0 + 2.028848e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 100B, Trails: 75
# x0'' + 9.999281e+00x0 + 2.028848e-02x0x0x0 + 9.968401e-03x0' = 0
#
# noise 100B, Trails: 76
# x0'' + 9.999281e+00x0 + 9.968399e-03x0' + 6.025764e-03x0x0'x0' = 0
#
# noise 100B, Trails: 77
# x0'' + 9.999281e+00x0 + 2.028848e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 100B, Trails: 78
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 100B, Trails: 79
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968398e-03x0' = 0
#
# noise 100B, Trails: 80
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 100B, Trails: 81
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 100B, Trails: 82
# x0'' + 9.999281e+00x0 + 9.968399e-03x0' + 6.025767e-03x0x0'x0' = 0
#
# noise 100B, Trails: 83
# x0'' + 9.999281e+00x0 + 2.028848e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 100B, Trails: 84
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968397e-03x0' = 0
#
# noise 100B, Trails: 85
# x0'' + 9.999281e+00x0 + 9.968399e-03x0' + 6.025759e-03x0x0'x0' = 0
#
# noise 100B, Trails: 86
# x0'' + 9.999281e+00x0 + 9.968404e-03x0' + 6.025764e-03x0x0'x0' = 0
#
# noise 100B, Trails: 87
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 100B, Trails: 88
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 100B, Trails: 89
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 100B, Trails: 90
# x0'' + 9.999281e+00x0 + 9.968402e-03x0' + 6.025759e-03x0x0'x0' = 0
#
# noise 100B, Trails: 91
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968398e-03x0' = 0
#
# noise 100B, Trails: 92
# x0'' + 9.999281e+00x0 + 2.028848e-02x0x0x0 + 9.968402e-03x0' = 0
#
# noise 100B, Trails: 93
# x0'' + 9.999281e+00x0 + 9.968400e-03x0' + 6.025767e-03x0x0'x0' = 0
#
# noise 100B, Trails: 94
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968401e-03x0' = 0
#
# noise 100B, Trails: 95
# x0'' + 9.999281e+00x0 + 2.028845e-02x0x0x0 + 9.968397e-03x0' = 0
#
# noise 100B, Trails: 96
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968401e-03x0' = 0
#
# noise 100B, Trails: 97
# x0'' + 9.999281e+00x0 + 9.968402e-03x0' + 6.025768e-03x0x0'x0' = 0
#
# noise 100B, Trails: 98
# x0'' + 9.999281e+00x0 + 9.968400e-03x0' + 6.025761e-03x0x0'x0' = 0
#
# noise 100B, Trails: 99
# x0'' + 9.999281e+00x0 + 2.028849e-02x0x0x0 + 9.968398e-03x0' = 0
#
# noise 90B, Trails: 0
# x0'' + 9.999281e+00x0 + 9.968406e-03x0' + 6.025769e-03x0x0'x0' = 0
#
# noise 90B, Trails: 1
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 90B, Trails: 2
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 90B, Trails: 3
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968409e-03x0' = 0
#
# noise 90B, Trails: 4
# x0'' + 9.999281e+00x0 + 2.028853e-02x0x0x0 + 9.968401e-03x0' = 0
#
# noise 90B, Trails: 5
# x0'' + 9.999281e+00x0 + 2.028845e-02x0x0x0 + 9.968401e-03x0' = 0
#
# noise 90B, Trails: 6
# x0'' + 9.999282e+00x0 + 2.028839e-02x0x0x0 + 9.968394e-03x0' = 0
#
# noise 90B, Trails: 7
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968402e-03x0' = 0
#
# noise 90B, Trails: 8
# x0'' + 9.999281e+00x0 + 2.028844e-02x0x0x0 + 9.968393e-03x0' = 0
#
# noise 90B, Trails: 9
# x0'' + 9.999281e+00x0 + 2.028844e-02x0x0x0 + 9.968402e-03x0' = 0
#
# noise 90B, Trails: 10
# x0'' + 9.999281e+00x0 + 2.028845e-02x0x0x0 + 9.968402e-03x0' = 0
#
# noise 90B, Trails: 11
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968402e-03x0' = 0
#
# noise 90B, Trails: 12
# x0'' + 9.999282e+00x0 + 2.028837e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 90B, Trails: 13
# x0'' + 9.999281e+00x0 + 9.968402e-03x0' + 6.025774e-03x0x0'x0' = 0
#
# noise 90B, Trails: 14
# x0'' + 9.999281e+00x0 + 9.968396e-03x0' + 6.025771e-03x0x0'x0' = 0
#
# noise 90B, Trails: 15
# x0'' + 9.999281e+00x0 + 2.028844e-02x0x0x0 + 9.968408e-03x0' = 0
#
# noise 90B, Trails: 16
# x0'' + 9.999281e+00x0 + 9.968413e-03x0' + 6.025783e-03x0x0'x0' = 0
#
# noise 90B, Trails: 17
# x0'' + 9.999281e+00x0 + 2.028848e-02x0x0x0 + 9.968392e-03x0' = 0
#
# noise 90B, Trails: 18
# x0'' + 9.999281e+00x0 + 2.028844e-02x0x0x0 + 9.968402e-03x0' = 0
#
# noise 90B, Trails: 19
# x0'' + 9.999281e+00x0 + 2.028850e-02x0x0x0 + 9.968398e-03x0' = 0
#
# noise 90B, Trails: 20
# x0'' + 9.999281e+00x0 + 2.028848e-02x0x0x0 + 9.968406e-03x0' = 0
#
# noise 90B, Trails: 21
# x0'' + 9.999281e+00x0 + 9.968394e-03x0' + 6.025761e-03x0x0'x0' = 0
#
# noise 90B, Trails: 22
# x0'' + 9.999282e+00x0 + 2.028841e-02x0x0x0 + 9.968395e-03x0' = 0
#
# noise 90B, Trails: 23
# x0'' + 9.999281e+00x0 + 2.028848e-02x0x0x0 + 9.968398e-03x0' = 0
#
# noise 90B, Trails: 24
# x0'' + 9.999281e+00x0 + 2.028845e-02x0x0x0 + 9.968394e-03x0' = 0
#
# noise 90B, Trails: 25
# x0'' + 9.999281e+00x0 + 9.968408e-03x0' + 6.025763e-03x0x0'x0' = 0
#
# noise 90B, Trails: 26
# x0'' + 9.999281e+00x0 + 2.028851e-02x0x0x0 + 9.968395e-03x0' = 0
#
# noise 90B, Trails: 27
# x0'' + 9.999282e+00x0 + 9.968402e-03x0' + 6.025749e-03x0x0'x0' = 0
#
# noise 90B, Trails: 28
# x0'' + 9.999281e+00x0 + 9.968395e-03x0' + 6.025785e-03x0x0'x0' = 0
#
# noise 90B, Trails: 29
# x0'' + 9.999281e+00x0 + 2.028843e-02x0x0x0 + 9.968407e-03x0' = 0
#
# noise 90B, Trails: 30
# x0'' + 9.999281e+00x0 + 2.028848e-02x0x0x0 + 9.968405e-03x0' = 0
#
# noise 90B, Trails: 31
# x0'' + 9.999281e+00x0 + 9.968396e-03x0' + 6.025770e-03x0x0'x0' = 0
#
# noise 90B, Trails: 32
# x0'' + 9.999282e+00x0 + 9.968397e-03x0' + 6.025745e-03x0x0'x0' = 0
#
# noise 90B, Trails: 33
# x0'' + 9.999281e+00x0 + 2.028845e-02x0x0x0 + 9.968394e-03x0' = 0
#
# noise 90B, Trails: 34
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 90B, Trails: 35
# x0'' + 9.999281e+00x0 + 2.028843e-02x0x0x0 + 9.968391e-03x0' = 0
#
# noise 90B, Trails: 36
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968415e-03x0' = 0
#
# noise 90B, Trails: 37
# x0'' + 9.999281e+00x0 + 2.028848e-02x0x0x0 + 9.968401e-03x0' = 0
#
# noise 90B, Trails: 38
# x0'' + 9.999280e+00x0 + 2.028858e-02x0x0x0 + 9.968398e-03x0' = 0
#
# noise 90B, Trails: 39
# x0'' + 9.999281e+00x0 + 9.968385e-03x0' + 6.025759e-03x0x0'x0' = 0
#
# noise 90B, Trails: 40
# x0'' + 9.999281e+00x0 + 9.968401e-03x0' + 6.025758e-03x0x0'x0' = 0
#
# noise 90B, Trails: 41
# x0'' + 9.999281e+00x0 + 2.028845e-02x0x0x0 + 9.968401e-03x0' = 0
#
# noise 90B, Trails: 42
# x0'' + 9.999281e+00x0 + 2.028854e-02x0x0x0 + 9.968404e-03x0' = 0
#
# noise 90B, Trails: 43
# x0'' + 9.999281e+00x0 + 2.028851e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 90B, Trails: 44
# x0'' + 9.999281e+00x0 + 2.028850e-02x0x0x0 + 9.968398e-03x0' = 0
#
# noise 90B, Trails: 45
# x0'' + 9.999280e+00x0 + 2.028857e-02x0x0x0 + 9.968392e-03x0' = 0
#
# noise 90B, Trails: 46
# x0'' + 9.999281e+00x0 + 2.028850e-02x0x0x0 + 9.968414e-03x0' = 0
#
# noise 90B, Trails: 47
# x0'' + 9.999280e+00x0 + 9.968392e-03x0' + 6.025788e-03x0x0'x0' = 0
#
# noise 90B, Trails: 48
# x0'' + 9.999281e+00x0 + 9.968391e-03x0' + 6.025775e-03x0x0'x0' = 0
#
# noise 90B, Trails: 49
# x0'' + 9.999281e+00x0 + 9.968401e-03x0' + 6.025781e-03x0x0'x0' = 0
#
# noise 90B, Trails: 50
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968402e-03x0' = 0
#
# noise 90B, Trails: 51
# x0'' + 9.999281e+00x0 + 9.968398e-03x0' + 6.025763e-03x0x0'x0' = 0
#
# noise 90B, Trails: 52
# x0'' + 9.999281e+00x0 + 2.028843e-02x0x0x0 + 9.968393e-03x0' = 0
#
# noise 90B, Trails: 53
# x0'' + 9.999281e+00x0 + 9.968410e-03x0' + 6.025756e-03x0x0'x0' = 0
#
# noise 90B, Trails: 54
# x0'' + 9.999281e+00x0 + 9.968390e-03x0' + 6.025755e-03x0x0'x0' = 0
#
# noise 90B, Trails: 55
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968403e-03x0' = 0
#
# noise 90B, Trails: 56
# x0'' + 9.999281e+00x0 + 9.968389e-03x0' + 6.025771e-03x0x0'x0' = 0
#
# noise 90B, Trails: 57
# x0'' + 9.999281e+00x0 + 2.028844e-02x0x0x0 + 9.968401e-03x0' = 0
#
# noise 90B, Trails: 58
# x0'' + 9.999282e+00x0 + 2.028842e-02x0x0x0 + 9.968404e-03x0' = 0
#
# noise 90B, Trails: 59
# x0'' + 9.999281e+00x0 + 2.028845e-02x0x0x0 + 9.968402e-03x0' = 0
#
# noise 90B, Trails: 60
# x0'' + 9.999281e+00x0 + 9.968403e-03x0' + 6.025766e-03x0x0'x0' = 0
#
# noise 90B, Trails: 61
# x0'' + 9.999281e+00x0 + 2.028845e-02x0x0x0 + 9.968388e-03x0' = 0
#
# noise 90B, Trails: 62
# x0'' + 9.999281e+00x0 + 9.968397e-03x0' + 6.025779e-03x0x0'x0' = 0
#
# noise 90B, Trails: 63
# x0'' + 9.999282e+00x0 + 2.028839e-02x0x0x0 + 9.968403e-03x0' = 0
#
# noise 90B, Trails: 64
# x0'' + 9.999282e+00x0 + 2.028842e-02x0x0x0 + 9.968406e-03x0' = 0
#
# noise 90B, Trails: 65
# x0'' + 9.999281e+00x0 + 2.028851e-02x0x0x0 + 9.968406e-03x0' = 0
#
# noise 90B, Trails: 66
# x0'' + 9.999281e+00x0 + 2.028845e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 90B, Trails: 67
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968406e-03x0' = 0
#
# noise 90B, Trails: 68
# x0'' + 9.999282e+00x0 + 2.028842e-02x0x0x0 + 9.968403e-03x0' = 0
#
# noise 90B, Trails: 69
# x0'' + 9.999282e+00x0 + 2.028843e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 90B, Trails: 70
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968395e-03x0' = 0
#
# noise 90B, Trails: 71
# x0'' + 9.999280e+00x0 + 2.028858e-02x0x0x0 + 9.968396e-03x0' = 0
#
# noise 90B, Trails: 72
# x0'' + 9.999281e+00x0 + 2.028849e-02x0x0x0 + 9.968403e-03x0' = 0
#
# noise 90B, Trails: 73
# x0'' + 9.999281e+00x0 + 2.028850e-02x0x0x0 + 9.968403e-03x0' = 0
#
# noise 90B, Trails: 74
# x0'' + 9.999281e+00x0 + 9.968399e-03x0' + 6.025757e-03x0x0'x0' = 0
#
# noise 90B, Trails: 75
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968404e-03x0' = 0
#
# noise 90B, Trails: 76
# x0'' + 9.999282e+00x0 + 2.028839e-02x0x0x0 + 9.968392e-03x0' = 0
#
# noise 90B, Trails: 77
# x0'' + 9.999281e+00x0 + 2.028850e-02x0x0x0 + 9.968402e-03x0' = 0
#
# noise 90B, Trails: 78
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968401e-03x0' = 0
#
# noise 90B, Trails: 79
# x0'' + 9.999281e+00x0 + 9.968402e-03x0' + 6.025786e-03x0x0'x0' = 0
#
# noise 90B, Trails: 80
# x0'' + 9.999282e+00x0 + 2.028838e-02x0x0x0 + 9.968401e-03x0' = 0
#
# noise 90B, Trails: 81
# x0'' + 9.999281e+00x0 + 2.028842e-02x0x0x0 + 9.968403e-03x0' = 0
#
# noise 90B, Trails: 82
# x0'' + 9.999281e+00x0 + 2.028851e-02x0x0x0 + 9.968390e-03x0' = 0
#
# noise 90B, Trails: 83
# x0'' + 9.999282e+00x0 + 2.028841e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 90B, Trails: 84
# x0'' + 9.999281e+00x0 + 2.028843e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 90B, Trails: 85
# x0'' + 9.999280e+00x0 + 9.968393e-03x0' + 6.025791e-03x0x0'x0' = 0
#
# noise 90B, Trails: 86
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 90B, Trails: 87
# x0'' + 9.999281e+00x0 + 9.968406e-03x0' + 6.025764e-03x0x0'x0' = 0
#
# noise 90B, Trails: 88
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968405e-03x0' = 0
#
# noise 90B, Trails: 89
# x0'' + 9.999281e+00x0 + 2.028854e-02x0x0x0 + 9.968395e-03x0' = 0
#
# noise 90B, Trails: 90
# x0'' + 9.999281e+00x0 + 2.028850e-02x0x0x0 + 9.968395e-03x0' = 0
#
# noise 90B, Trails: 91
# x0'' + 9.999281e+00x0 + 2.028851e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 90B, Trails: 92
# x0'' + 9.999281e+00x0 + 2.028849e-02x0x0x0 + 9.968398e-03x0' = 0
#
# noise 90B, Trails: 93
# x0'' + 9.999280e+00x0 + 9.968403e-03x0' + 6.025788e-03x0x0'x0' = 0
#
# noise 90B, Trails: 94
# x0'' + 9.999281e+00x0 + 2.028844e-02x0x0x0 + 9.968391e-03x0' = 0
#
# noise 90B, Trails: 95
# x0'' + 9.999281e+00x0 + 9.968391e-03x0' + 6.025781e-03x0x0'x0' = 0
#
# noise 90B, Trails: 96
# x0'' + 9.999281e+00x0 + 2.028850e-02x0x0x0 + 9.968387e-03x0' = 0
#
# noise 90B, Trails: 97
# x0'' + 9.999281e+00x0 + 9.968395e-03x0' + 6.025785e-03x0x0'x0' = 0
#
# noise 90B, Trails: 98
# x0'' + 9.999281e+00x0 + 2.028845e-02x0x0x0 + 9.968410e-03x0' = 0
#
# noise 90B, Trails: 99
# x0'' + 9.999281e+00x0 + 9.968407e-03x0' + 6.025757e-03x0x0'x0' = 0
#
# noise 80B, Trails: 0
# x0'' + 9.999280e+00x0 + 9.968398e-03x0' + 6.025818e-03x0x0'x0' = 0
#
# noise 80B, Trails: 1
# x0'' + 9.999281e+00x0 + 2.028850e-02x0x0x0 + 9.968375e-03x0' = 0
#
# noise 80B, Trails: 2
# x0'' + 9.999282e+00x0 + 2.028834e-02x0x0x0 + 9.968418e-03x0' = 0
#
# noise 80B, Trails: 3
# x0'' + 9.999281e+00x0 + 2.028856e-02x0x0x0 + 9.968393e-03x0' = 0
#
# noise 80B, Trails: 4
# x0'' + 9.999282e+00x0 + 2.028839e-02x0x0x0 + 9.968398e-03x0' = 0
#
# noise 80B, Trails: 5
# x0'' + 9.999281e+00x0 + 9.968389e-03x0' + 6.025765e-03x0x0'x0' = 0
#
# noise 80B, Trails: 6
# x0'' + 9.999281e+00x0 + 9.968409e-03x0' + 6.025756e-03x0x0'x0' = 0
#
# noise 80B, Trails: 7
# x0'' + 9.999282e+00x0 + 9.968410e-03x0' + 6.025746e-03x0x0'x0' = 0
#
# noise 80B, Trails: 8
# x0'' + 9.999280e+00x0 + 9.968426e-03x0' + 6.025791e-03x0x0'x0' = 0
#
# noise 80B, Trails: 9
# x0'' + 9.999281e+00x0 + 2.028849e-02x0x0x0 + 9.968424e-03x0' = 0
#
# noise 80B, Trails: 10
# x0'' + 9.999280e+00x0 + 9.968418e-03x0' + 6.025805e-03x0x0'x0' = 0
#
# noise 80B, Trails: 11
# x0'' + 9.999281e+00x0 + 2.028847e-02x0x0x0 + 9.968376e-03x0' = 0
#
# noise 80B, Trails: 12
# x0'' + 9.999282e+00x0 + 2.028841e-02x0x0x0 + 9.968363e-03x0' = 0
#
# noise 80B, Trails: 13
# x0'' + 9.999282e+00x0 + 2.028840e-02x0x0x0 + 9.968414e-03x0' = 0
#
# noise 80B, Trails: 14
# x0'' + 9.999280e+00x0 + 9.968393e-03x0' + 6.025805e-03x0x0'x0' = 0
#
# noise 80B, Trails: 15
# x0'' + 9.999281e+00x0 + 9.968410e-03x0' + 6.025777e-03x0x0'x0' = 0
#
# noise 80B, Trails: 16
# x0'' + 9.999280e+00x0 + 9.968434e-03x0' + 6.025813e-03x0x0'x0' = 0
#
# noise 80B, Trails: 17
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968423e-03x0' = 0
#
# noise 80B, Trails: 18
# x0'' + 9.999283e+00x0 + 2.028829e-02x0x0x0 + 9.968415e-03x0' = 0
#
# noise 80B, Trails: 19
# x0'' + 9.999281e+00x0 + 2.028849e-02x0x0x0 + 9.968416e-03x0' = 0
#
# noise 80B, Trails: 20
# x0'' + 9.999281e+00x0 + 2.028844e-02x0x0x0 + 9.968393e-03x0' = 0
#
# noise 80B, Trails: 21
# x0'' + 9.999281e+00x0 + 9.968399e-03x0' + 6.025773e-03x0x0'x0' = 0
#
# noise 80B, Trails: 22
# x0'' + 9.999281e+00x0 + 2.028852e-02x0x0x0 + 9.968391e-03x0' = 0
#
# noise 80B, Trails: 23
# x0'' + 9.999282e+00x0 + 9.968382e-03x0' + 6.025747e-03x0x0'x0' = 0
#
# noise 80B, Trails: 24
# x0'' + 9.999282e+00x0 + 9.968411e-03x0' + 6.025732e-03x0x0'x0' = 0
#
# noise 80B, Trails: 25
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968412e-03x0' = 0
#
# noise 80B, Trails: 26
# x0'' + 9.999281e+00x0 + 2.028850e-02x0x0x0 + 9.968407e-03x0' = 0
#
# noise 80B, Trails: 27
# x0'' + 9.999282e+00x0 + 2.028835e-02x0x0x0 + 9.968381e-03x0' = 0
#
# noise 80B, Trails: 28
# x0'' + 9.999281e+00x0 + 2.028843e-02x0x0x0 + 9.968441e-03x0' = 0
#
# noise 80B, Trails: 29
# x0'' + 9.999280e+00x0 + 9.968404e-03x0' + 6.025794e-03x0x0'x0' = 0
#
# noise 80B, Trails: 30
# x0'' + 9.999281e+00x0 + 2.028843e-02x0x0x0 + 9.968408e-03x0' = 0
#
# noise 80B, Trails: 31
# x0'' + 9.999281e+00x0 + 9.968408e-03x0' + 6.025770e-03x0x0'x0' = 0
#
# noise 80B, Trails: 32
# x0'' + 9.999284e+00x0 + 2.028818e-02x0x0x0 + 9.968390e-03x0' = 0
#
# noise 80B, Trails: 33
# x0'' + 9.999280e+00x0 + 9.968422e-03x0' + 6.025802e-03x0x0'x0' = 0
#
# noise 80B, Trails: 34
# x0'' + 9.999279e+00x0 + 2.028871e-02x0x0x0 + 9.968398e-03x0' = 0
#
# noise 80B, Trails: 35
# x0'' + 9.999282e+00x0 + 2.028833e-02x0x0x0 + 9.968410e-03x0' = 0
#
# noise 80B, Trails: 36
# x0'' + 9.999281e+00x0 + 2.028844e-02x0x0x0 + 9.968405e-03x0' = 0
#
# noise 80B, Trails: 37
# x0'' + 9.999281e+00x0 + 9.968391e-03x0' + 6.025773e-03x0x0'x0' = 0
#
# noise 80B, Trails: 38
# x0'' + 9.999281e+00x0 + 9.968435e-03x0' + 6.025793e-03x0x0'x0' = 0
#
# noise 80B, Trails: 39
# x0'' + 9.999281e+00x0 + 9.968394e-03x0' + 6.025756e-03x0x0'x0' = 0
#
# noise 80B, Trails: 40
# x0'' + 9.999284e+00x0 + 9.968424e-03x0' + 6.025664e-03x0x0'x0' = 0
#
# noise 80B, Trails: 41
# x0'' + 9.999282e+00x0 + 2.028833e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 80B, Trails: 42
# x0'' + 9.999281e+00x0 + 2.028851e-02x0x0x0 + 9.968378e-03x0' = 0
#
# noise 80B, Trails: 43
# x0'' + 9.999279e+00x0 + 2.028865e-02x0x0x0 + 9.968410e-03x0' = 0
#
# noise 80B, Trails: 44
# x0'' + 9.999282e+00x0 + 9.968406e-03x0' + 6.025737e-03x0x0'x0' = 0
#
# noise 80B, Trails: 45
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968380e-03x0' = 0
#
# noise 80B, Trails: 46
# x0'' + 9.999283e+00x0 + 2.028832e-02x0x0x0 + 9.968387e-03x0' = 0
#
# noise 80B, Trails: 47
# x0'' + 9.999281e+00x0 + 9.968426e-03x0' + 6.025785e-03x0x0'x0' = 0
#
# noise 80B, Trails: 48
# x0'' + 9.999282e+00x0 + 2.028834e-02x0x0x0 + 9.968404e-03x0' = 0
#
# noise 80B, Trails: 49
# x0'' + 9.999280e+00x0 + 9.968395e-03x0' + 6.025789e-03x0x0'x0' = 0
#
# noise 80B, Trails: 50
# x0'' + 9.999280e+00x0 + 9.968386e-03x0' + 6.025806e-03x0x0'x0' = 0
#
# noise 80B, Trails: 51
# x0'' + 9.999282e+00x0 + 2.028830e-02x0x0x0 + 9.968417e-03x0' = 0
#
# noise 80B, Trails: 52
# x0'' + 9.999281e+00x0 + 2.028852e-02x0x0x0 + 9.968426e-03x0' = 0
#
# noise 80B, Trails: 53
# x0'' + 9.999280e+00x0 + 9.968380e-03x0' + 6.025809e-03x0x0'x0' = 0
#
# noise 80B, Trails: 54
# x0'' + 9.999279e+00x0 + 2.028869e-02x0x0x0 + 9.968384e-03x0' = 0
#
# noise 80B, Trails: 55
# x0'' + 9.999281e+00x0 + 9.968411e-03x0' + 6.025778e-03x0x0'x0' = 0
#
# noise 80B, Trails: 56
# x0'' + 9.999282e+00x0 + 9.968405e-03x0' + 6.025751e-03x0x0'x0' = 0
#
# noise 80B, Trails: 57
# x0'' + 9.999281e+00x0 + 2.028843e-02x0x0x0 + 9.968364e-03x0' = 0
#
# noise 80B, Trails: 58
# x0'' + 9.999282e+00x0 + 2.028841e-02x0x0x0 + 9.968387e-03x0' = 0
#
# noise 80B, Trails: 59
# x0'' + 9.999281e+00x0 + 2.028844e-02x0x0x0 + 9.968380e-03x0' = 0
#
# noise 80B, Trails: 60
# x0'' + 9.999282e+00x0 + 2.028843e-02x0x0x0 + 9.968368e-03x0' = 0
#
# noise 80B, Trails: 61
# x0'' + 9.999281e+00x0 + 2.028851e-02x0x0x0 + 9.968397e-03x0' = 0
#
# noise 80B, Trails: 62
# x0'' + 9.999282e+00x0 + 2.028839e-02x0x0x0 + 9.968410e-03x0' = 0
#
# noise 80B, Trails: 63
# x0'' + 9.999282e+00x0 + 2.028839e-02x0x0x0 + 9.968392e-03x0' = 0
#
# noise 80B, Trails: 64
# x0'' + 9.999282e+00x0 + 2.028839e-02x0x0x0 + 9.968385e-03x0' = 0
#
# noise 80B, Trails: 65
# x0'' + 9.999283e+00x0 + 2.028829e-02x0x0x0 + 9.968403e-03x0' = 0
#
# noise 80B, Trails: 66
# x0'' + 9.999282e+00x0 + 2.028829e-02x0x0x0 + 9.968376e-03x0' = 0
#
# noise 80B, Trails: 67
# x0'' + 9.999281e+00x0 + 2.028850e-02x0x0x0 + 9.968410e-03x0' = 0
#
# noise 80B, Trails: 68
# x0'' + 9.999282e+00x0 + 2.028833e-02x0x0x0 + 9.968402e-03x0' = 0
#
# noise 80B, Trails: 69
# x0'' + 9.999281e+00x0 + 9.968399e-03x0' + 6.025779e-03x0x0'x0' = 0
#
# noise 80B, Trails: 70
# x0'' + 9.999281e+00x0 + 2.028850e-02x0x0x0 + 9.968417e-03x0' = 0
#
# noise 80B, Trails: 71
# x0'' + 9.999282e+00x0 + 9.968412e-03x0' + 6.025742e-03x0x0'x0' = 0
#
# noise 80B, Trails: 72
# x0'' + 9.999280e+00x0 + 2.028857e-02x0x0x0 + 9.968406e-03x0' = 0
#
# noise 80B, Trails: 73
# x0'' + 9.999281e+00x0 + 9.968387e-03x0' + 6.025756e-03x0x0'x0' = 0
#
# noise 80B, Trails: 74
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968382e-03x0' = 0
#
# noise 80B, Trails: 75
# x0'' + 9.999280e+00x0 + 9.968432e-03x0' + 6.025793e-03x0x0'x0' = 0
#
# noise 80B, Trails: 76
# x0'' + 9.999281e+00x0 + 2.028853e-02x0x0x0 + 9.968391e-03x0' = 0
#
# noise 80B, Trails: 77
# x0'' + 9.999282e+00x0 + 9.968424e-03x0' + 6.025708e-03x0x0'x0' = 0
#
# noise 80B, Trails: 78
# x0'' + 9.999280e+00x0 + 2.028857e-02x0x0x0 + 9.968390e-03x0' = 0
#
# noise 80B, Trails: 79
# x0'' + 9.999280e+00x0 + 2.028861e-02x0x0x0 + 9.968391e-03x0' = 0
#
# noise 80B, Trails: 80
# x0'' + 9.999281e+00x0 + 2.028854e-02x0x0x0 + 9.968387e-03x0' = 0
#
# noise 80B, Trails: 81
# x0'' + 9.999282e+00x0 + 9.968378e-03x0' + 6.025732e-03x0x0'x0' = 0
#
# noise 80B, Trails: 82
# x0'' + 9.999280e+00x0 + 2.028859e-02x0x0x0 + 9.968417e-03x0' = 0
#
# noise 80B, Trails: 83
# x0'' + 9.999282e+00x0 + 9.968404e-03x0' + 6.025735e-03x0x0'x0' = 0
#
# noise 80B, Trails: 84
# x0'' + 9.999283e+00x0 + 2.028823e-02x0x0x0 + 9.968411e-03x0' = 0
#
# noise 80B, Trails: 85
# x0'' + 9.999281e+00x0 + 2.028850e-02x0x0x0 + 9.968387e-03x0' = 0
#
# noise 80B, Trails: 86
# x0'' + 9.999281e+00x0 + 2.028853e-02x0x0x0 + 9.968384e-03x0' = 0
#
# noise 80B, Trails: 87
# x0'' + 9.999281e+00x0 + 9.968406e-03x0' + 6.025767e-03x0x0'x0' = 0
#
# noise 80B, Trails: 88
# x0'' + 9.999281e+00x0 + 2.028852e-02x0x0x0 + 9.968407e-03x0' = 0
#
# noise 80B, Trails: 89
# x0'' + 9.999281e+00x0 + 9.968401e-03x0' + 6.025754e-03x0x0'x0' = 0
#
# noise 80B, Trails: 90
# x0'' + 9.999281e+00x0 + 2.028856e-02x0x0x0 + 9.968423e-03x0' = 0
#
# noise 80B, Trails: 91
# x0'' + 9.999281e+00x0 + 2.028849e-02x0x0x0 + 9.968397e-03x0' = 0
#
# noise 80B, Trails: 92
# x0'' + 9.999281e+00x0 + 2.028852e-02x0x0x0 + 9.968403e-03x0' = 0
#
# noise 80B, Trails: 93
# x0'' + 9.999281e+00x0 + 9.968418e-03x0' + 6.025788e-03x0x0'x0' = 0
#
# noise 80B, Trails: 94
# x0'' + 9.999283e+00x0 + 2.028819e-02x0x0x0 + 9.968415e-03x0' = 0
#
# noise 80B, Trails: 95
# x0'' + 9.999281e+00x0 + 2.028843e-02x0x0x0 + 9.968405e-03x0' = 0
#
# noise 80B, Trails: 96
# x0'' + 9.999282e+00x0 + 2.028840e-02x0x0x0 + 9.968370e-03x0' = 0
#
# noise 80B, Trails: 97
# x0'' + 9.999279e+00x0 + 9.968359e-03x0' + 6.025837e-03x0x0'x0' = 0
#
# noise 80B, Trails: 98
# x0'' + 9.999280e+00x0 + 2.028855e-02x0x0x0 + 9.968348e-03x0' = 0
#
# noise 80B, Trails: 99
# x0'' + 9.999282e+00x0 + 2.028835e-02x0x0x0 + 9.968437e-03x0' = 0
#
# noise 70B, Trails: 0
# x0'' + 9.999287e+00x0 + 2.028773e-02x0x0x0 + 9.968463e-03x0' = 0
#
# noise 70B, Trails: 1
# x0'' + 9.999276e+00x0 + 2.028902e-02x0x0x0 + 9.968346e-03x0' = 0
#
# noise 70B, Trails: 2
# x0'' + 9.999285e+00x0 + 2.028795e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 70B, Trails: 3
# x0'' + 9.999280e+00x0 + 2.028857e-02x0x0x0 + 9.968439e-03x0' = 0
#
# noise 70B, Trails: 4
# x0'' + 9.999278e+00x0 + 2.028887e-02x0x0x0 + 9.968435e-03x0' = 0
#
# noise 70B, Trails: 5
# x0'' + 9.999284e+00x0 + 2.028806e-02x0x0x0 + 9.968491e-03x0' = 0
#
# noise 70B, Trails: 6
# x0'' + 9.999283e+00x0 + 2.028822e-02x0x0x0 + 9.968381e-03x0' = 0
#
# noise 70B, Trails: 7
# x0'' + 9.999284e+00x0 + 2.028813e-02x0x0x0 + 9.968424e-03x0' = 0
#
# noise 70B, Trails: 8
# x0'' + 9.999285e+00x0 + 2.028802e-02x0x0x0 + 9.968399e-03x0' = 0
#
# noise 70B, Trails: 9
# x0'' + 9.999281e+00x0 + 9.968326e-03x0' + 6.025774e-03x0x0'x0' = 0
#
# noise 70B, Trails: 10
# x0'' + 9.999284e+00x0 + 2.028815e-02x0x0x0 + 9.968388e-03x0' = 0
#
# noise 70B, Trails: 11
# x0'' + 9.999279e+00x0 + 9.968370e-03x0' + 6.025827e-03x0x0'x0' = 0
#
# noise 70B, Trails: 12
# x0'' + 9.999282e+00x0 + 9.968340e-03x0' + 6.025754e-03x0x0'x0' = 0
#
# noise 70B, Trails: 13
# x0'' + 9.999283e+00x0 + 9.968358e-03x0' + 6.025715e-03x0x0'x0' = 0
#
# noise 70B, Trails: 14
# x0'' + 9.999281e+00x0 + 2.028856e-02x0x0x0 + 9.968451e-03x0' = 0
#
# noise 70B, Trails: 15
# x0'' + 9.999279e+00x0 + 2.028865e-02x0x0x0 + 9.968377e-03x0' = 0
#
# noise 70B, Trails: 16
# x0'' + 9.999281e+00x0 + 2.028853e-02x0x0x0 + 9.968436e-03x0' = 0
#
# noise 70B, Trails: 17
# x0'' + 9.999278e+00x0 + 2.028884e-02x0x0x0 + 9.968411e-03x0' = 0
#
# noise 70B, Trails: 18
# x0'' + 9.999286e+00x0 + 2.028796e-02x0x0x0 + 9.968421e-03x0' = 0
#
# noise 70B, Trails: 19
# x0'' + 9.999289e+00x0 + 9.968503e-03x0' + 6.025479e-03x0x0'x0' = 0
#
# noise 70B, Trails: 20
# x0'' + 9.999278e+00x0 + 9.968474e-03x0' + 6.025895e-03x0x0'x0' = 0
#
# noise 70B, Trails: 21
# x0'' + 9.999282e+00x0 + 2.028835e-02x0x0x0 + 9.968413e-03x0' = 0
#
# noise 70B, Trails: 22
# x0'' + 9.999274e+00x0 + 9.968474e-03x0' + 6.025998e-03x0x0'x0' = 0
#
# noise 70B, Trails: 23
# x0'' + 9.999280e+00x0 + 2.028866e-02x0x0x0 + 9.968412e-03x0' = 0
#
# noise 70B, Trails: 24
# x0'' + 9.999275e+00x0 + 9.968389e-03x0' + 6.025975e-03x0x0'x0' = 0
#
# noise 70B, Trails: 25
# x0'' + 9.999277e+00x0 + 9.968476e-03x0' + 6.025914e-03x0x0'x0' = 0
#
# noise 70B, Trails: 26
# x0'' + 9.999285e+00x0 + 9.968408e-03x0' + 6.025602e-03x0x0'x0' = 0
#
# noise 70B, Trails: 27
# x0'' + 9.999278e+00x0 + 9.968320e-03x0' + 6.025886e-03x0x0'x0' = 0
#
# noise 70B, Trails: 28
# x0'' + 9.999282e+00x0 + 9.968362e-03x0' + 6.025756e-03x0x0'x0' = 0
#
# noise 70B, Trails: 29
# x0'' + 9.999277e+00x0 + 2.028885e-02x0x0x0 + 9.968403e-03x0' = 0
#
# noise 70B, Trails: 30
# x0'' + 9.999275e+00x0 + 2.028930e-02x0x0x0 + 9.968315e-03x0' = 0
#
# noise 70B, Trails: 31
# x0'' + 9.999277e+00x0 + 9.968386e-03x0' + 6.025907e-03x0x0'x0' = 0
#
# noise 70B, Trails: 32
# x0'' + 9.999288e+00x0 + 9.968511e-03x0' + 6.025520e-03x0x0'x0' = 0
#
# noise 70B, Trails: 33
# x0'' + 9.999281e+00x0 + 2.028840e-02x0x0x0 + 9.968365e-03x0' = 0
#
# noise 70B, Trails: 34
# x0'' + 9.999288e+00x0 + 9.968395e-03x0' + 6.025531e-03x0x0'x0' = 0
#
# noise 70B, Trails: 35
# x0'' + 9.999277e+00x0 + 2.028892e-02x0x0x0 + 9.968402e-03x0' = 0
#
# noise 70B, Trails: 36
# x0'' + 9.999275e+00x0 + 9.968532e-03x0' + 6.025991e-03x0x0'x0' = 0
#
# noise 70B, Trails: 37
# x0'' + 9.999279e+00x0 + 2.028867e-02x0x0x0 + 9.968391e-03x0' = 0
#
# noise 70B, Trails: 38
# x0'' + 9.999281e+00x0 + 2.028850e-02x0x0x0 + 9.968385e-03x0' = 0
#
# noise 70B, Trails: 39
# x0'' + 9.999283e+00x0 + 9.968439e-03x0' + 6.025700e-03x0x0'x0' = 0
#
# noise 70B, Trails: 40
# x0'' + 9.999283e+00x0 + 9.968375e-03x0' + 6.025700e-03x0x0'x0' = 0
#
# noise 70B, Trails: 41
# x0'' + 9.999288e+00x0 + 9.968391e-03x0' + 6.025523e-03x0x0'x0' = 0
#
# noise 70B, Trails: 42
# x0'' + 9.999283e+00x0 + 9.968334e-03x0' + 6.025721e-03x0x0'x0' = 0
#
# noise 70B, Trails: 43
# x0'' + 9.999283e+00x0 + 9.968333e-03x0' + 6.025649e-03x0x0'x0' = 0
#
# noise 70B, Trails: 44
# x0'' + 9.999274e+00x0 + 9.968435e-03x0' + 6.025991e-03x0x0'x0' = 0
#
# noise 70B, Trails: 45
# x0'' + 9.999284e+00x0 + 9.968356e-03x0' + 6.025654e-03x0x0'x0' = 0
#
# noise 70B, Trails: 46
# x0'' + 9.999283e+00x0 + 9.968363e-03x0' + 6.025721e-03x0x0'x0' = 0
#
# noise 70B, Trails: 47
# x0'' + 9.999283e+00x0 + 2.028826e-02x0x0x0 + 9.968486e-03x0' = 0
#
# noise 70B, Trails: 48
# x0'' + 9.999277e+00x0 + 2.028891e-02x0x0x0 + 9.968511e-03x0' = 0
#
# noise 70B, Trails: 49
# x0'' + 9.999281e+00x0 + 2.028834e-02x0x0x0 + 9.968356e-03x0' = 0
#
# noise 70B, Trails: 50
# x0'' + 9.999281e+00x0 + 2.028846e-02x0x0x0 + 9.968433e-03x0' = 0
#
# noise 70B, Trails: 51
# x0'' + 9.999285e+00x0 + 2.028790e-02x0x0x0 + 9.968394e-03x0' = 0
#
# noise 70B, Trails: 52
# x0'' + 9.999276e+00x0 + 2.028904e-02x0x0x0 + 9.968460e-03x0' = 0
#
# noise 70B, Trails: 53
# x0'' + 9.999284e+00x0 + 2.028800e-02x0x0x0 + 9.968413e-03x0' = 0
#
# noise 70B, Trails: 54
# x0'' + 9.999286e+00x0 + 9.968317e-03x0' + 6.025600e-03x0x0'x0' = 0
#
# noise 70B, Trails: 55
# x0'' + 9.999287e+00x0 + 9.968426e-03x0' + 6.025568e-03x0x0'x0' = 0
#
# noise 70B, Trails: 56
# x0'' + 9.999275e+00x0 + 9.968484e-03x0' + 6.025969e-03x0x0'x0' = 0
#
# noise 70B, Trails: 57
# x0'' + 9.999283e+00x0 + 2.028827e-02x0x0x0 + 9.968513e-03x0' = 0
#
# noise 70B, Trails: 58
# x0'' + 9.999283e+00x0 + 2.028833e-02x0x0x0 + 9.968425e-03x0' = 0
#
# noise 70B, Trails: 59
# x0'' + 9.999279e+00x0 + 2.028876e-02x0x0x0 + 9.968269e-03x0' = 0
#
# noise 70B, Trails: 60
# x0'' + 9.999283e+00x0 + 9.968375e-03x0' + 6.025727e-03x0x0'x0' = 0
#
# noise 70B, Trails: 61
# x0'' + 9.999279e+00x0 + 2.028882e-02x0x0x0 + 9.968478e-03x0' = 0
#
# noise 70B, Trails: 62
# x0'' + 9.999277e+00x0 + 2.028905e-02x0x0x0 + 9.968330e-03x0' = 0
#
# noise 70B, Trails: 63
# x0'' + 9.999282e+00x0 + 2.028836e-02x0x0x0 + 9.968400e-03x0' = 0
#
# noise 70B, Trails: 64
# x0'' + 9.999284e+00x0 + 2.028819e-02x0x0x0 + 9.968374e-03x0' = 0
#
# noise 70B, Trails: 65
# x0'' + 9.999281e+00x0 + 2.028857e-02x0x0x0 + 9.968377e-03x0' = 0
#
# noise 70B, Trails: 66
# x0'' + 9.999286e+00x0 + 9.968410e-03x0' + 6.025577e-03x0x0'x0' = 0
#
# noise 70B, Trails: 67
# x0'' + 9.999282e+00x0 + 9.968364e-03x0' + 6.025757e-03x0x0'x0' = 0
#
# noise 70B, Trails: 68
# x0'' + 9.999280e+00x0 + 2.028867e-02x0x0x0 + 9.968325e-03x0' = 0
#
# noise 70B, Trails: 69
# x0'' + 9.999285e+00x0 + 9.968296e-03x0' + 6.025598e-03x0x0'x0' = 0
#
# noise 70B, Trails: 70
# x0'' + 9.999285e+00x0 + 2.028793e-02x0x0x0 + 9.968483e-03x0' = 0
#
# noise 70B, Trails: 71
# x0'' + 9.999283e+00x0 + 2.028837e-02x0x0x0 + 9.968420e-03x0' = 0
#
# noise 70B, Trails: 72
# x0'' + 9.999287e+00x0 + 9.968427e-03x0' + 6.025536e-03x0x0'x0' = 0
#
# noise 70B, Trails: 73
# x0'' + 9.999282e+00x0 + 2.028833e-02x0x0x0 + 9.968412e-03x0' = 0
#
# noise 70B, Trails: 74
# x0'' + 9.999283e+00x0 + 9.968451e-03x0' + 6.025690e-03x0x0'x0' = 0
#
# noise 70B, Trails: 75
# x0'' + 9.999277e+00x0 + 2.028892e-02x0x0x0 + 9.968374e-03x0' = 0
#
# noise 70B, Trails: 76
# x0'' + 9.999281e+00x0 + 2.028863e-02x0x0x0 + 9.968539e-03x0' = 0
#
# noise 70B, Trails: 77
# x0'' + 9.999284e+00x0 + 2.028812e-02x0x0x0 + 9.968485e-03x0' = 0
#
# noise 70B, Trails: 78
# x0'' + 9.999281e+00x0 + 2.028855e-02x0x0x0 + 9.968537e-03x0' = 0
#
# noise 70B, Trails: 79
# x0'' + 9.999280e+00x0 + 9.968343e-03x0' + 6.025836e-03x0x0'x0' = 0
#
# noise 70B, Trails: 80
# x0'' + 9.999286e+00x0 + 2.028791e-02x0x0x0 + 9.968440e-03x0' = 0
#
# noise 70B, Trails: 81
# x0'' + 9.999277e+00x0 + 9.968412e-03x0' + 6.025912e-03x0x0'x0' = 0
#
# noise 70B, Trails: 82
# x0'' + 9.999279e+00x0 + 2.028879e-02x0x0x0 + 9.968348e-03x0' = 0
#
# noise 70B, Trails: 83
# x0'' + 9.999284e+00x0 + 9.968442e-03x0' + 6.025662e-03x0x0'x0' = 0
#
# noise 70B, Trails: 84
# x0'' + 9.999279e+00x0 + 2.028871e-02x0x0x0 + 9.968404e-03x0' = 0
#
# noise 70B, Trails: 85
# x0'' + 9.999282e+00x0 + 9.968404e-03x0' + 6.025761e-03x0x0'x0' = 0
#
# noise 70B, Trails: 86
# x0'' + 9.999277e+00x0 + 2.028890e-02x0x0x0 + 9.968447e-03x0' = 0
#
# noise 70B, Trails: 87
# x0'' + 9.999284e+00x0 + 9.968416e-03x0' + 6.025659e-03x0x0'x0' = 0
#
# noise 70B, Trails: 88
# x0'' + 9.999279e+00x0 + 9.968338e-03x0' + 6.025861e-03x0x0'x0' = 0
#
# noise 70B, Trails: 89
# x0'' + 9.999278e+00x0 + 2.028890e-02x0x0x0 + 9.968316e-03x0' = 0
#
# noise 70B, Trails: 90
# x0'' + 9.999283e+00x0 + 2.028826e-02x0x0x0 + 9.968433e-03x0' = 0
#
# noise 70B, Trails: 91
# x0'' + 9.999288e+00x0 + 2.028776e-02x0x0x0 + 9.968385e-03x0' = 0
#
# noise 70B, Trails: 92
# x0'' + 9.999289e+00x0 + 9.968473e-03x0' + 6.025482e-03x0x0'x0' = 0
#
# noise 70B, Trails: 93
# x0'' + 9.999278e+00x0 + 2.028886e-02x0x0x0 + 9.968419e-03x0' = 0
#
# noise 70B, Trails: 94
# x0'' + 9.999281e+00x0 + 9.968362e-03x0' + 6.025783e-03x0x0'x0' = 0
#
# noise 70B, Trails: 95
# x0'' + 9.999274e+00x0 + 9.968433e-03x0' + 6.026012e-03x0x0'x0' = 0
#
# noise 70B, Trails: 96
# x0'' + 9.999275e+00x0 + 9.968392e-03x0' + 6.025977e-03x0x0'x0' = 0
#
# noise 70B, Trails: 97
# x0'' + 9.999285e+00x0 + 2.028804e-02x0x0x0 + 9.968430e-03x0' = 0
#
# noise 70B, Trails: 98
# x0'' + 9.999281e+00x0 + 2.028864e-02x0x0x0 + 9.968417e-03x0' = 0
#
# noise 70B, Trails: 99
# x0'' + 9.999284e+00x0 + 2.028810e-02x0x0x0 + 9.968380e-03x0' = 0
#
# noise 60B, Trails: 0
# x0'' + 9.999303e+00x0 + 9.968606e-03x0' + 6.024982e-03x0x0'x0' = 0
#
# noise 60B, Trails: 1
# x0'' + 9.999287e+00x0 + 9.968500e-03x0' + 6.025587e-03x0x0'x0' = 0
#
# noise 60B, Trails: 2
# x0'' + 9.999269e+00x0 + 9.968370e-03x0' + 6.026140e-03x0x0'x0' = 0
#
# noise 60B, Trails: 3
# x0'' + 9.999274e+00x0 + 2.028951e-02x0x0x0 + 9.968164e-03x0' = 0
#
# noise 60B, Trails: 4
# x0'' + 9.999261e+00x0 + 2.029088e-02x0x0x0 + 9.968462e-03x0' = 0
#
# noise 60B, Trails: 5
# x0'' + 9.999286e+00x0 + 2.028800e-02x0x0x0 + 9.968230e-03x0' = 0
#
# noise 60B, Trails: 6
# x0'' + 9.999271e+00x0 + 9.968322e-03x0' + 6.026121e-03x0x0'x0' = 0
#
# noise 60B, Trails: 7
# x0'' + 9.999290e+00x0 + 2.028726e-02x0x0x0 + 9.968255e-03x0' = 0
#
# noise 60B, Trails: 8
# x0'' + 9.999294e+00x0 + 2.028691e-02x0x0x0 + 9.968459e-03x0' = 0
#
# noise 60B, Trails: 9
# x0'' + 9.999257e+00x0 + 2.029176e-02x0x0x0 + 9.968631e-03x0' = 0
#
# noise 60B, Trails: 10
# x0'' + 9.999269e+00x0 + 2.028993e-02x0x0x0 + 9.968541e-03x0' = 0
#
# noise 60B, Trails: 11
# x0'' + 9.999293e+00x0 + 2.028727e-02x0x0x0 + 9.968412e-03x0' = 0
#
# noise 60B, Trails: 12
# x0'' + 9.999263e+00x0 + 2.029074e-02x0x0x0 + 9.968449e-03x0' = 0
#
# noise 60B, Trails: 13
# x0'' + 9.999311e+00x0 + 9.968431e-03x0' + 6.024723e-03x0x0'x0' = 0
#
# noise 60B, Trails: 14
# x0'' + 9.999268e+00x0 + 2.029033e-02x0x0x0 + 9.968881e-03x0' = 0
#
# noise 60B, Trails: 15
# x0'' + 9.999278e+00x0 + 2.028887e-02x0x0x0 + 9.968371e-03x0' = 0
#
# noise 60B, Trails: 16
# x0'' + 9.999277e+00x0 + 2.028908e-02x0x0x0 + 9.968269e-03x0' = 0
#
# noise 60B, Trails: 17
# x0'' + 9.999274e+00x0 + 2.028916e-02x0x0x0 + 9.968197e-03x0' = 0
#
# noise 60B, Trails: 18
# x0'' + 9.999272e+00x0 + 2.028949e-02x0x0x0 + 9.968468e-03x0' = 0
#
# noise 60B, Trails: 19
# x0'' + 9.999279e+00x0 + 2.028893e-02x0x0x0 + 9.968718e-03x0' = 0
#
# noise 60B, Trails: 20
# x0'' + 9.999275e+00x0 + 2.028935e-02x0x0x0 + 9.968485e-03x0' = 0
#
# noise 60B, Trails: 21
# x0'' + 9.999274e+00x0 + 2.028965e-02x0x0x0 + 9.968297e-03x0' = 0
#
# noise 60B, Trails: 22
# x0'' + 9.999265e+00x0 + 2.029034e-02x0x0x0 + 9.968511e-03x0' = 0
#
# noise 60B, Trails: 23
# x0'' + 9.999276e+00x0 + 2.028932e-02x0x0x0 + 9.968511e-03x0' = 0
#
# noise 60B, Trails: 24
# x0'' + 9.999292e+00x0 + 2.028710e-02x0x0x0 + 9.968396e-03x0' = 0
#
# noise 60B, Trails: 25
# x0'' + 9.999293e+00x0 + 2.028686e-02x0x0x0 + 9.968525e-03x0' = 0
#
# noise 60B, Trails: 26
# x0'' + 9.999274e+00x0 + 2.028955e-02x0x0x0 + 9.968561e-03x0' = 0
#
# noise 60B, Trails: 27
# x0'' + 9.999277e+00x0 + 2.028896e-02x0x0x0 + 9.968507e-03x0' = 0
#
# noise 60B, Trails: 28
# x0'' + 9.999277e+00x0 + 2.028902e-02x0x0x0 + 9.968700e-03x0' = 0
#
# noise 60B, Trails: 29
# x0'' + 9.999271e+00x0 + 2.028946e-02x0x0x0 + 9.968352e-03x0' = 0
#
# noise 60B, Trails: 30
# x0'' + 9.999288e+00x0 + 9.968453e-03x0' + 6.025672e-03x0x0'x0' = 0
#
# noise 60B, Trails: 31
# x0'' + 9.999272e+00x0 + 2.028941e-02x0x0x0 + 9.968156e-03x0' = 0
#
# noise 60B, Trails: 32
# x0'' + 9.999282e+00x0 + 9.968390e-03x0' + 6.025723e-03x0x0'x0' = 0
#
# noise 60B, Trails: 33
# x0'' + 9.999290e+00x0 + 2.028752e-02x0x0x0 + 9.968306e-03x0' = 0
#
# noise 60B, Trails: 34
# x0'' + 9.999270e+00x0 + 2.028981e-02x0x0x0 + 9.968403e-03x0' = 0
#
# noise 60B, Trails: 35
# x0'' + 9.999299e+00x0 + 2.028611e-02x0x0x0 + 9.968279e-03x0' = 0
#
# noise 60B, Trails: 36
# x0'' + 9.999258e+00x0 + 2.029107e-02x0x0x0 + 9.968303e-03x0' = 0
#
# noise 60B, Trails: 37
# x0'' + 9.999274e+00x0 + 9.968550e-03x0' + 6.026016e-03x0x0'x0' = 0
#
# noise 60B, Trails: 38
# x0'' + 9.999261e+00x0 + 2.029056e-02x0x0x0 + 9.968590e-03x0' = 0
#
# noise 60B, Trails: 39
# x0'' + 9.999278e+00x0 + 2.028932e-02x0x0x0 + 9.968708e-03x0' = 0
#
# noise 60B, Trails: 40
# x0'' + 9.999285e+00x0 + 2.028828e-02x0x0x0 + 9.968120e-03x0' = 0
#
# noise 60B, Trails: 41
# x0'' + 9.999286e+00x0 + 9.968392e-03x0' + 6.025622e-03x0x0'x0' = 0
#
# noise 60B, Trails: 42
# x0'' + 9.999275e+00x0 + 2.028892e-02x0x0x0 + 9.968963e-03x0' = 0
#
# noise 60B, Trails: 43
# x0'' + 9.999271e+00x0 + 2.028997e-02x0x0x0 + 9.968355e-03x0' = 0
#
# noise 60B, Trails: 44
# x0'' + 9.999273e+00x0 + 2.028913e-02x0x0x0 + 9.968599e-03x0' = 0
#
# noise 60B, Trails: 45
# x0'' + 9.999285e+00x0 + 9.968381e-03x0' + 6.025597e-03x0x0'x0' = 0
#
# noise 60B, Trails: 46
# x0'' + 9.999288e+00x0 + 2.028762e-02x0x0x0 + 9.968346e-03x0' = 0
#
# noise 60B, Trails: 47
# x0'' + 9.999276e+00x0 + 2.028914e-02x0x0x0 + 9.968328e-03x0' = 0
#
# noise 60B, Trails: 48
# x0'' + 9.999262e+00x0 + 2.029081e-02x0x0x0 + 9.968325e-03x0' = 0
#
# noise 60B, Trails: 49
# x0'' + 9.999259e+00x0 + 2.029102e-02x0x0x0 + 9.968388e-03x0' = 0
#
# noise 60B, Trails: 50
# x0'' + 9.999290e+00x0 + 2.028748e-02x0x0x0 + 9.968054e-03x0' = 0
#
# noise 60B, Trails: 51
# x0'' + 9.999280e+00x0 + 9.968440e-03x0' + 6.025795e-03x0x0'x0' = 0
#
# noise 60B, Trails: 52
# x0'' + 9.999292e+00x0 + 2.028734e-02x0x0x0 + 9.968268e-03x0' = 0
#
# noise 60B, Trails: 53
# x0'' + 9.999282e+00x0 + 9.968130e-03x0' + 6.025699e-03x0x0'x0' = 0
#
# noise 60B, Trails: 54
# x0'' + 9.999291e+00x0 + 2.028730e-02x0x0x0 + 9.968427e-03x0' = 0
#
# noise 60B, Trails: 55
# x0'' + 9.999280e+00x0 + 9.968262e-03x0' + 6.025885e-03x0x0'x0' = 0
#
# noise 60B, Trails: 56
# x0'' + 9.999266e+00x0 + 9.968501e-03x0' + 6.026336e-03x0x0'x0' = 0
#
# noise 60B, Trails: 57
# x0'' + 9.999273e+00x0 + 9.968325e-03x0' + 6.026019e-03x0x0'x0' = 0
#
# noise 60B, Trails: 58
# x0'' + 9.999280e+00x0 + 9.968408e-03x0' + 6.025777e-03x0x0'x0' = 0
#
# noise 60B, Trails: 59
# x0'' + 9.999290e+00x0 + 9.968331e-03x0' + 6.025504e-03x0x0'x0' = 0
#
# noise 60B, Trails: 60
# x0'' + 9.999294e+00x0 + 2.028683e-02x0x0x0 + 9.968546e-03x0' = 0
#
# noise 60B, Trails: 61
# x0'' + 9.999266e+00x0 + 2.029052e-02x0x0x0 + 9.968225e-03x0' = 0
#
# noise 60B, Trails: 62
# x0'' + 9.999260e+00x0 + 2.029081e-02x0x0x0 + 9.968389e-03x0' = 0
#
# noise 60B, Trails: 63
# x0'' + 9.999271e+00x0 + 2.028953e-02x0x0x0 + 9.968358e-03x0' = 0
#
# noise 60B, Trails: 64
# x0'' + 9.999274e+00x0 + 2.028918e-02x0x0x0 + 9.968735e-03x0' = 0
#
# noise 60B, Trails: 65
# x0'' + 9.999283e+00x0 + 9.968130e-03x0' + 6.025645e-03x0x0'x0' = 0
#
# noise 60B, Trails: 66
# x0'' + 9.999295e+00x0 + 2.028666e-02x0x0x0 + 9.968452e-03x0' = 0
#
# noise 60B, Trails: 67
# x0'' + 9.999285e+00x0 + 9.968240e-03x0' + 6.025708e-03x0x0'x0' = 0
#
# noise 60B, Trails: 68
# x0'' + 9.999306e+00x0 + 9.968208e-03x0' + 6.024865e-03x0x0'x0' = 0
#
# noise 60B, Trails: 69
# x0'' + 9.999266e+00x0 + 9.968378e-03x0' + 6.026269e-03x0x0'x0' = 0
#
# noise 60B, Trails: 70
# x0'' + 9.999270e+00x0 + 2.028957e-02x0x0x0 + 9.968191e-03x0' = 0
#
# noise 60B, Trails: 71
# x0'' + 9.999280e+00x0 + 2.028850e-02x0x0x0 + 9.968131e-03x0' = 0
#
# noise 60B, Trails: 72
# x0'' + 9.999263e+00x0 + 9.968651e-03x0' + 6.026367e-03x0x0'x0' = 0
#
# noise 60B, Trails: 73
# x0'' + 9.999283e+00x0 + 2.028845e-02x0x0x0 + 9.968484e-03x0' = 0
#
# noise 60B, Trails: 74
# x0'' + 9.999258e+00x0 + 2.029111e-02x0x0x0 + 9.968502e-03x0' = 0
#
# noise 60B, Trails: 75
# x0'' + 9.999294e+00x0 + 2.028702e-02x0x0x0 + 9.968310e-03x0' = 0
#
# noise 60B, Trails: 76
# x0'' + 9.999284e+00x0 + 9.968548e-03x0' + 6.025673e-03x0x0'x0' = 0
#
# noise 60B, Trails: 77
# x0'' + 9.999280e+00x0 + 9.968613e-03x0' + 6.025842e-03x0x0'x0' = 0
#
# noise 60B, Trails: 78
# x0'' + 9.999282e+00x0 + 2.028845e-02x0x0x0 + 9.968536e-03x0' = 0
#
# noise 60B, Trails: 79
# x0'' + 9.999267e+00x0 + 2.029023e-02x0x0x0 + 9.968466e-03x0' = 0
#
# noise 60B, Trails: 80
# x0'' + 9.999286e+00x0 + 2.028784e-02x0x0x0 + 9.968572e-03x0' = 0
#
# noise 60B, Trails: 81
# x0'' + 9.999274e+00x0 + 2.028947e-02x0x0x0 + 9.968512e-03x0' = 0
#
# noise 60B, Trails: 82
# x0'' + 9.999271e+00x0 + 9.968282e-03x0' + 6.026206e-03x0x0'x0' = 0
#
# noise 60B, Trails: 83
# x0'' + 9.999289e+00x0 + 2.028747e-02x0x0x0 + 9.968282e-03x0' = 0
#
# noise 60B, Trails: 84
# x0'' + 9.999289e+00x0 + 2.028749e-02x0x0x0 + 9.968680e-03x0' = 0
#
# noise 60B, Trails: 85
# x0'' + 9.999275e+00x0 + 9.968193e-03x0' + 6.026006e-03x0x0'x0' = 0
#
# noise 60B, Trails: 86
# x0'' + 9.999274e+00x0 + 9.968216e-03x0' + 6.025985e-03x0x0'x0' = 0
#
# noise 60B, Trails: 87
# x0'' + 9.999299e+00x0 + 2.028613e-02x0x0x0 + 9.968478e-03x0' = 0
#
# noise 60B, Trails: 88
# x0'' + 9.999279e+00x0 + 2.028885e-02x0x0x0 + 9.968303e-03x0' = 0
#
# noise 60B, Trails: 89
# x0'' + 9.999283e+00x0 + 2.028800e-02x0x0x0 + 9.968274e-03x0' = 0
#
# noise 60B, Trails: 90
# x0'' + 9.999272e+00x0 + 2.028941e-02x0x0x0 + 9.968156e-03x0' = 0
#
# noise 60B, Trails: 91
# x0'' + 9.999281e+00x0 + 9.968485e-03x0' + 6.025715e-03x0x0'x0' = 0
#
# noise 60B, Trails: 92
# x0'' + 9.999274e+00x0 + 2.028908e-02x0x0x0 + 9.968269e-03x0' = 0
#
# noise 60B, Trails: 93
# x0'' + 9.999255e+00x0 + 2.029148e-02x0x0x0 + 9.968632e-03x0' = 0
#
# noise 60B, Trails: 94
# x0'' + 9.999273e+00x0 + 2.028948e-02x0x0x0 + 9.968451e-03x0' = 0
#
# noise 60B, Trails: 95
# x0'' + 9.999288e+00x0 + 9.968137e-03x0' + 6.025491e-03x0x0'x0' = 0
#
# noise 60B, Trails: 96
# x0'' + 9.999284e+00x0 + 2.028811e-02x0x0x0 + 9.968221e-03x0' = 0
#
# noise 60B, Trails: 97
# x0'' + 9.999285e+00x0 + 9.968625e-03x0' + 6.025666e-03x0x0'x0' = 0
#
# noise 60B, Trails: 98
# x0'' + 9.999320e+00x0 + 2.028388e-02x0x0x0 + 9.968473e-03x0' = 0
#
# noise 60B, Trails: 99
# x0'' + 9.999291e+00x0 + 9.968552e-03x0' + 6.025360e-03x0x0'x0' = 0
#
# noise 50B, Trails: 0
# x0'' + 9.999450e+00x0 + 9.968294e-03x0' + 6.019789e-03x0x0'x0' = 0
#
# noise 50B, Trails: 1
# x0'' + 9.999244e+00x0 + 2.029360e-02x0x0x0 + 9.969416e-03x0' = 0
#
# noise 50B, Trails: 2
# x0'' + 9.999271e+00x0 + 9.967379e-03x0' + 6.026035e-03x0x0'x0' = 0
#
# noise 50B, Trails: 3
# x0'' + 9.999281e+00x0 + 2.028837e-02x0x0x0 + 9.968702e-03x0' = 0
#
# noise 50B, Trails: 4
# x0'' + 9.999269e+00x0 + 9.968777e-03x0' + 6.026230e-03x0x0'x0' = 0
#
# noise 50B, Trails: 5
# x0'' + 9.999296e+00x0 + 2.028662e-02x0x0x0 + 9.967953e-03x0' = 0
#
# noise 50B, Trails: 6
# x0'' + 9.999269e+00x0 + 2.028947e-02x0x0x0 + 9.968669e-03x0' = 0
#
# noise 50B, Trails: 7
# x0'' + 9.999255e+00x0 + 2.029132e-02x0x0x0 + 9.969253e-03x0' = 0
#
# noise 50B, Trails: 8
# x0'' + 9.999243e+00x0 + 2.029269e-02x0x0x0 + 9.967799e-03x0' = 0
#
# noise 50B, Trails: 9
# x0'' + 9.999257e+00x0 + 2.029120e-02x0x0x0 + 9.968378e-03x0' = 0
#
# noise 50B, Trails: 10
# x0'' + 9.999318e+00x0 + 9.967134e-03x0' + 6.024752e-03x0x0'x0' = 0
#
# noise 50B, Trails: 11
# x0'' + 9.999306e+00x0 + 2.028553e-02x0x0x0 + 9.968323e-03x0' = 0
#
# noise 50B, Trails: 12
# x0'' + 9.999254e+00x0 + 2.029157e-02x0x0x0 + 9.968719e-03x0' = 0
#
# noise 50B, Trails: 13
# x0'' + 9.999272e+00x0 + 2.028952e-02x0x0x0 + 9.967222e-03x0' = 0
#
# noise 50B, Trails: 14
# x0'' + 9.999253e+00x0 + 2.029172e-02x0x0x0 + 9.967553e-03x0' = 0
#
# noise 50B, Trails: 15
# x0'' + 9.999218e+00x0 + 2.029557e-02x0x0x0 + 9.968905e-03x0' = 0
#
# noise 50B, Trails: 16
# x0'' + 9.999217e+00x0 + 2.029682e-02x0x0x0 + 9.968674e-03x0' = 0
#
# noise 50B, Trails: 17
# x0'' + 9.999309e+00x0 + 2.028483e-02x0x0x0 + 9.968786e-03x0' = 0
#
# noise 50B, Trails: 18
# x0'' + 9.999245e+00x0 + 2.029284e-02x0x0x0 + 9.969067e-03x0' = 0
#
# noise 50B, Trails: 19
# x0'' + 9.999278e+00x0 + 9.968187e-03x0' + 6.025899e-03x0x0'x0' = 0
#
# noise 50B, Trails: 20
# x0'' + 9.999204e+00x0 + 2.029669e-02x0x0x0 + 9.968310e-03x0' = 0
#
# noise 50B, Trails: 21
# x0'' + 9.999313e+00x0 + 9.969464e-03x0' + 6.024248e-03x0x0'x0' = 0
#
# noise 50B, Trails: 22
# x0'' + 9.999236e+00x0 + 2.029362e-02x0x0x0 + 9.968181e-03x0' = 0
#
# noise 50B, Trails: 23
# x0'' + 9.999238e+00x0 + 2.029488e-02x0x0x0 + 9.968148e-03x0' = 0
#
# noise 50B, Trails: 24
# x0'' + 9.999324e+00x0 + 9.968389e-03x0' + 6.024119e-03x0x0'x0' = 0
#
# noise 50B, Trails: 25
# x0'' + 9.999297e+00x0 + 2.028608e-02x0x0x0 + 9.969663e-03x0' = 0
#
# noise 50B, Trails: 26
# x0'' + 9.999234e+00x0 + 9.967199e-03x0' + 6.027597e-03x0x0'x0' = 0
#
# noise 50B, Trails: 27
# x0'' + 9.999235e+00x0 + 2.029384e-02x0x0x0 + 9.969237e-03x0' = 0
#
# noise 50B, Trails: 28
# x0'' + 9.999241e+00x0 + 2.029331e-02x0x0x0 + 9.968521e-03x0' = 0
#
# noise 50B, Trails: 29
# x0'' + 9.999286e+00x0 + 2.028755e-02x0x0x0 + 9.968176e-03x0' = 0
#
# noise 50B, Trails: 30
# x0'' + 9.999298e+00x0 + 2.028626e-02x0x0x0 + 9.968451e-03x0' = 0
#
# noise 50B, Trails: 31
# x0'' + 9.999259e+00x0 + 2.029080e-02x0x0x0 + 9.968347e-03x0' = 0
#
# noise 50B, Trails: 32
# x0'' + 9.999222e+00x0 + 2.029580e-02x0x0x0 + 9.969289e-03x0' = 0
#
# noise 50B, Trails: 33
# x0'' + 9.999244e+00x0 + 2.029196e-02x0x0x0 + 9.967499e-03x0' = 0
#
# noise 50B, Trails: 34
# x0'' + 9.999234e+00x0 + 9.968468e-03x0' + 6.027661e-03x0x0'x0' = 0
#
# noise 50B, Trails: 35
# x0'' + 9.999282e+00x0 + 2.028796e-02x0x0x0 + 9.968773e-03x0' = 0
#
# noise 50B, Trails: 36
# x0'' + 9.999281e+00x0 + 2.028924e-02x0x0x0 + 9.968495e-03x0' = 0
#
# noise 50B, Trails: 37
# x0'' + 9.999255e+00x0 + 9.968937e-03x0' + 6.026682e-03x0x0'x0' = 0
#
# noise 50B, Trails: 38
# x0'' + 9.999327e+00x0 + 2.028273e-02x0x0x0 + 9.969071e-03x0' = 0
#
# noise 50B, Trails: 39
# x0'' + 9.999302e+00x0 + 2.028658e-02x0x0x0 + 9.969819e-03x0' = 0
#
# noise 50B, Trails: 40
# ...
#
# noise 20B, Trails: 27
# x0'' + 9.789306e+00x0 + 9.911911e-03x0' + 1.343088e-02x0x0'x0' = 0
#
# noise 20B, Trails: 28
# x0'' + 1.049982e+01x0 + -1.580545e-01x0x0x0 + 9.599847e-03x0x0x0x0x0 + 9.883759e-03x0' = 0
#
# noise 20B, Trails: 29
# x0'' + 1.010086e+01x0 + 8.002187e-04x0x0x0x0x0 + 9.909722e-03x0' = 0
#
# noise 20B, Trails: 30
# x0'' + 1.020242e+01x0 + 9.910330e-03x0' = 0
#
# noise 20B, Trails: 31
# x0'' + 9.587768e+00x0 + 1.651980e-01x0x0x0 + -7.776999e-03x0x0x0x0x0 + 9.883536e-03x0' = 0
#
# noise 20B, Trails: 32
# x0'' + 1.022949e+01x0 + 9.890935e-03x0' = 0
#
# noise 20B, Trails: 33
# x0'' + 9.990634e+00x0 + 9.906584e-03x0' + 6.315673e-03x0x0'x0' = 0
#
# noise 20B, Trails: 34
# x0'' + 1.002537e+01x0 + 9.889085e-03x0' + 6.293697e-05x0x0'x0'x0'x0' = 0
#
# noise 20B, Trails: 35
# x0'' + 1.037131e+01x0 + 9.904518e-03x0' + -7.178937e-03x0x0'x0' = 0
#
# noise 20B, Trails: 36
# x0'' + 1.002220e+01x0 + 1.308724e-03x0x0x0x0x0 + 9.893347e-03x0' = 0
#
# noise 20B, Trails: 37
# x0'' + 9.754998e+00x0 + 4.923294e-02x0x0x0 + 9.918340e-03x0' = 0
#
# noise 20B, Trails: 38
# x0'' + 9.813502e+00x0 + 9.891259e-03x0' + 1.260032e-02x0x0'x0' = 0
#
# noise 20B, Trails: 39
# x0'' + 1.003652e+01x0 + 1.211906e-03x0x0x0x0x0 + 9.927377e-03x0' = 0
#
# noise 20B, Trails: 40
# x0'' + 9.849419e+00x0 + 9.897666e-03x0' + 1.133002e-02x0x0'x0' = 0
#
# noise 20B, Trails: 41
# x0'' + 9.834805e+00x0 + 3.997438e-02x0x0x0 + 9.894178e-03x0' = 0
#
# noise 20B, Trails: 42
# x0'' + 1.010086e+01x0 + 9.870668e-03x0' = 0
#
# noise 20B, Trails: 43
# x0'' + 1.010086e+01x0 + 9.865068e-03x0' = 0
#
# noise 20B, Trails: 44
# x0'' + 9.955312e+00x0 + 9.887346e-03x0' + 7.545772e-03x0x0'x0' = 0
#
# noise 20B, Trails: 45
# x0'' + 1.017956e+01x0 + 9.926942e-03x0' = 0
#
# noise 20B, Trails: 46
# x0'' + 1.018028e+01x0 + 9.885806e-03x0' = 0
#
# noise 20B, Trails: 47
# x0'' + 9.971326e+00x0 + 2.373629e-02x0x0x0 + 9.865560e-03x0' = 0
#
# noise 20B, Trails: 48
# x0'' + 1.024690e+01x0 + 9.913980e-03x0' = 0
#
# noise 20B, Trails: 49
# x0'' + 9.952372e+00x0 + 9.871819e-03x0' + 7.672809e-03x0x0'x0' = 0
#
# noise 20B, Trails: 50
# x0'' + 1.014348e+01x0 + 9.889230e-03x0' + 2.564306e-05x0x0'x0'x0'x0' = 0
#
# noise 20B, Trails: 51
# x0'' + 1.010086e+01x0 + 9.865758e-03x0' = 0
#
# noise 20B, Trails: 52
# x0'' + 1.014616e+01x0 + 9.919166e-03x0' = 0
#
# noise 20B, Trails: 53
# x0'' + 9.712661e+00x0 + 1.212147e-01x0x0x0 + 9.889550e-03x0' + -2.677878e-03x0x0x0x0'x0' = 0
#
# noise 20B, Trails: 54
# x0'' + 1.010086e+01x0 + 8.009020e-04x0x0x0x0x0 + 9.877132e-03x0' = 0
#
# noise 20B, Trails: 55
# x0'' + 1.026947e+01x0 + -1.173839e-02x0x0x0 + 9.891347e-03x0' = 0
#
# noise 20B, Trails: 56
# x0'' + 9.881117e+00x0 + 3.428802e-02x0x0x0 + 9.914760e-03x0' = 0
#
# noise 20B, Trails: 57
# x0'' + 9.921503e+00x0 + 2.942437e-02x0x0x0 + 9.918760e-03x0' = 0
#
# noise 20B, Trails: 58
# x0'' + 9.721367e+00x0 + 9.889236e-03x0' + 3.476119e-02x0x0'x0' + -2.534508e-04x0x0'x0'x0'x0' = 0
#
# noise 20B, Trails: 59
# x0'' + 1.001921e+01x0 + 1.328773e-03x0x0x0x0x0 + 9.896053e-03x0' = 0
#
# noise 20B, Trails: 60
# x0'' + 1.010086e+01x0 + 9.884813e-03x0' + 3.952009e-04x0x0x0x0'x0' = 0
#
# noise 20B, Trails: 61
# x0'' + 1.004302e+01x0 + 9.893749e-03x0' + 5.803851e-04x0x0x0x0'x0' = 0
#
# noise 20B, Trails: 62
# x0'' + 9.468449e+00x0 + 9.887456e-03x0' + 2.468603e-02x0x0'x0' = 0
#
# noise 20B, Trails: 63
# x0'' + 1.017213e+01x0 + 9.911668e-03x0' = 0
#
# noise 20B, Trails: 64
# x0'' + 1.002564e+01x0 + 1.287636e-03x0x0x0x0x0 + 9.917263e-03x0' = 0
#
# noise 20B, Trails: 65
# x0'' + 1.010086e+01x0 + 7.991734e-04x0x0x0x0x0 + 9.923849e-03x0' = 0
#
# noise 20B, Trails: 66
# x0'' + 9.930806e+00x0 + 9.910728e-03x0' + 8.445571e-03x0x0'x0' = 0
#
# noise 20B, Trails: 67
# x0'' + 1.025531e+01x0 + -1.016343e-02x0x0x0 + 9.912154e-03x0' = 0
#
# noise 20B, Trails: 68
# x0'' + 1.002698e+01x0 + 9.903267e-03x0' + 6.327560e-04x0x0x0x0'x0' = 0
#
# noise 20B, Trails: 69
# x0'' + 1.018464e+01x0 + 9.905452e-03x0' = 0
#
# noise 20B, Trails: 70
# x0'' + 1.046318e+01x0 + -1.414756e-01x0x0x0 + 9.901153e-03x0' + 4.274783e-03x0x0x0x0'x0' = 0
#
# noise 20B, Trails: 71
# x0'' + 9.975549e+00x0 + 9.898452e-03x0' + 6.867679e-03x0x0'x0' = 0
#
# noise 20B, Trails: 72
# x0'' + 9.958390e+00x0 + 2.531438e-02x0x0x0 + 9.912835e-03x0' = 0
#
# noise 20B, Trails: 73
# x0'' + 1.045505e+01x0 + -1.402737e-01x0x0x0 + 9.899434e-03x0' + 4.265416e-03x0x0x0x0'x0' = 0
#
# noise 20B, Trails: 74
# x0'' + 9.907566e+00x0 + 3.128024e-02x0x0x0 + 9.867956e-03x0' = 0
#
# noise 20B, Trails: 75
# x0'' + 1.040623e+01x0 + -1.223317e-01x0x0x0 + 7.626380e-03x0x0x0x0x0 + 9.896581e-03x0' = 0
#
# noise 20B, Trails: 76
# x0'' + 1.010086e+01x0 + 9.936575e-03x0' = 0
#
# noise 20B, Trails: 77
# x0'' + 9.915623e+00x0 + 3.030163e-02x0x0x0 + 9.912807e-03x0' = 0
#
# noise 20B, Trails: 78
# x0'' + 9.761546e+00x0 + 4.836895e-02x0x0x0 + 9.887324e-03x0' = 0
#
# noise 20B, Trails: 79
# x0'' + 1.017126e+01x0 + 9.888832e-03x0' = 0
#
# noise 20B, Trails: 80
# x0'' + 9.571878e+00x0 + 9.899503e-03x0' + 5.060842e-02x0x0'x0' + -3.975223e-03x0x0x0x0'x0' = 0
#
# noise 20B, Trails: 81
# x0'' + 1.010086e+01x0 + 7.982004e-04x0x0x0x0x0 + 9.897438e-03x0' = 0
#
# noise 20B, Trails: 82
# x0'' + 9.949312e+00x0 + 9.914839e-03x0' + 7.843558e-03x0x0'x0' = 0
#
# noise 20B, Trails: 83
# x0'' + 1.030566e+01x0 + 9.929251e-03x0' + -4.778419e-03x0x0'x0' = 0
#
# noise 20B, Trails: 84
# x0'' + 1.004113e+01x0 + 9.877643e-03x0' + 5.815655e-05x0x0'x0'x0'x0' = 0
#
# noise 20B, Trails: 85
# x0'' + 9.816479e+00x0 + 4.225322e-02x0x0x0 + 9.915232e-03x0' = 0
#
# noise 20B, Trails: 86
# x0'' + 1.053641e+01x0 + -1.697850e-01x0x0x0 + 1.022041e-02x0x0x0x0x0 + 9.888346e-03x0' = 0
#
# noise 20B, Trails: 87
# x0'' + 1.018192e+01x0 + 9.892802e-03x0' = 0
#
# noise 20B, Trails: 88
# x0'' + 1.010086e+01x0 + 9.864675e-03x0' = 0
#
# noise 20B, Trails: 89
# x0'' + 1.001641e+01x0 + 9.896208e-03x0' + 6.669260e-04x0x0x0x0'x0' = 0
#
# noise 20B, Trails: 90
# x0'' + 1.019583e+01x0 + 9.925697e-03x0' = 0
#
# noise 20B, Trails: 91
# x0'' + 1.010086e+01x0 + 9.917455e-03x0' = 0
#
# noise 20B, Trails: 92
# x0'' + 1.030251e+01x0 + -8.879508e-02x0x0x0 + 9.891094e-03x0' + 2.912494e-03x0x0x0x0'x0' = 0
#
# noise 20B, Trails: 93
# x0'' + 1.030093e+01x0 + 9.875819e-03x0' + -4.667990e-03x0x0'x0' = 0
#
# noise 20B, Trails: 94
# x0'' + 1.010086e+01x0 + 9.918434e-03x0' = 0
#
# noise 20B, Trails: 95
# x0'' + 9.936982e+00x0 + 2.761831e-02x0x0x0 + 9.887967e-03x0' = 0
#
# noise 20B, Trails: 96
# x0'' + 1.010086e+01x0 + 9.894434e-03x0' + 3.965421e-04x0x0x0x0'x0' = 0
#
# noise 20B, Trails: 97
# x0'' + 1.010086e+01x0 + 9.915369e-03x0' = 0
#
# noise 20B, Trails: 98
# x0'' + 1.017381e+01x0 + 9.864515e-03x0' = 0
#
# noise 20B, Trails: 99
# x0'' + 1.036002e+01x0 + -1.079626e-01x0x0x0 + 9.894964e-03x0' + 3.379731e-04x0x0'x0'x0'x0' = 0
#
# noise 10B, Trails: 0
# x0'' + 1.061707e+01x0 + 9.447381e-03x0x0x0x0x0 + 9.305949e-03x0' + -4.951862e-02x0x0'x0' = 0
#
# noise 10B, Trails: 1
# x0'' + 1.012364e+01x0 + 9.192136e-03x0' + -5.671441e-03x0x0'x0' + 9.965813e-04x0x0x0x0'x0' = 0
#
# noise 10B, Trails: 2
# x0'' + 1.078812e+01x0 + 1.322922e-02x0x0x0x0x0 + 9.231181e-03x0' + -6.964882e-02x0x0'x0' = 0
#
# noise 10B, Trails: 3
# x0'' + 1.048338e+01x0 + -1.388063e-01x0x0x0 + 8.240236e-03x0x0x0x0x0 + 9.304879e-03x0' = 0
#
# noise 10B, Trails: 4
# x0'' + 1.046553e+01x0 + -3.392016e-02x0x0x0 + 9.303927e-03x0' = 0
#
# noise 10B, Trails: 5
# x0'' + 1.018354e+01x0 + -2.565783e-02x0x0x0 + 9.269724e-03x0' + 1.026770e-04x0x0'x0'x0'x0' = 0
#
# noise 10B, Trails: 6
# x0'' + 1.006069e+01x0 + 9.332295e-03x0' + 1.618144e-03x0x0'x0' + 3.273334e-04x0x0x0x0'x0' = 0
#
# noise 10B, Trails: 7
# x0'' + 1.048682e+01x0 + 9.243814e-03x0' + -4.155565e-02x0x0'x0' + 4.132161e-03x0x0x0x0'x0' = 0
#
# noise 10B, Trails: 8
# x0'' + 9.576974e+00x0 + 1.564202e-01x0x0x0 + 9.244494e-03x0' + -3.497070e-03x0x0x0x0'x0' = 0
#
# noise 10B, Trails: 9
# x0'' + 1.018833e+01x0 + -5.145047e-02x0x0x0 + 3.918659e-03x0x0x0x0x0 + 9.220419e-03x0' = 0
#
# noise 10B, Trails: 10
# x0'' + 1.022865e+01x0 + -5.258339e-02x0x0x0 + 3.716798e-03x0x0x0x0x0 + 9.320257e-03x0' = 0
#
# noise 10B, Trails: 11
# x0'' + 1.008655e+01x0 + 2.663338e-03x0x0x0x0x0 + 9.200014e-03x0' + -7.393506e-03x0x0'x0' = 0
#
# noise 10B, Trails: 12
# x0'' + 9.951091e+00x0 + 9.251915e-03x0' + 8.530139e-04x0x0x0x0'x0' = 0
#
# noise 10B, Trails: 13
# x0'' + 1.018566e+01x0 + 4.528854e-03x0x0x0x0x0 + 9.311622e-03x0' + -1.781403e-02x0x0'x0' = 0
#
# noise 10B, Trails: 14
# x0'' + 9.620288e+00x0 + 9.200611e-03x0' + 3.838579e-02x0x0'x0' + -2.678999e-03x0x0x0x0'x0' = 0
#
# noise 10B, Trails: 15
# x0'' + 9.863922e+00x0 + 9.239063e-03x0' = 0
#
# noise 10B, Trails: 16
# x0'' + 9.870811e+00x0 + 1.025293e-01x0x0x0 + -5.051012e-03x0x0x0x0x0 + 9.310022e-03x0' = 0
#
# noise 10B, Trails: 17
# x0'' + 1.016924e+01x0 + -1.856167e-02x0x0x0 + 1.678308e-03x0x0x0x0x0 + 9.240951e-03x0' = 0
#
# noise 10B, Trails: 18
# x0'' + 1.026750e+01x0 + 5.944398e-03x0x0x0x0x0 + 9.241395e-03x0' + -2.571629e-02x0x0'x0' = 0
#
# noise 10B, Trails: 19
# x0'' + 9.788603e+00x0 + 4.351136e-02x0x0x0 + 9.151979e-03x0' = 0
#
# noise 10B, Trails: 20
# x0'' + 9.539393e+00x0 + 9.238815e-03x0' + 4.997668e-02x0x0'x0' + -3.754733e-04x0x0'x0'x0'x0' = 0
#
# noise 10B, Trails: 21
# x0'' + 9.946643e+00x0 + 2.667882e-02x0x0x0 + 9.222833e-03x0' = 0
#
# noise 10B, Trails: 22
# x0'' + 1.026101e+01x0 + 9.272932e-03x0' + -2.159536e-02x0x0'x0' + 2.451553e-04x0x0'x0'x0'x0' = 0
#
# noise 10B, Trails: 23
# x0'' + 1.008149e+01x0 + 9.233602e-03x0' + 4.519647e-04x0x0x0x0'x0' = 0
#
# noise 10B, Trails: 24
# x0'' + 9.401987e+00x0 + 9.215108e-03x0' + 5.982025e-02x0x0'x0' + -4.499477e-04x0x0'x0'x0'x0' = 0
#
# noise 10B, Trails: 25
# x0'' + 1.037361e+01x0 + -9.089156e-02x0x0x0 + 5.572085e-03x0x0x0x0x0 + 9.335067e-03x0' = 0
#
# noise 10B, Trails: 26
# x0'' + 1.000165e+01x0 + 1.953205e-02x0x0x0 + 9.266838e-03x0' = 0
#
# noise 10B, Trails: 27
# x0'' + 9.651352e+00x0 + 1.428434e-01x0x0x0 + 9.368480e-03x0' + -3.223674e-04x0x0'x0'x0'x0' = 0
#
# noise 10B, Trails: 28
# x0'' + 1.007432e+01x0 + 1.340584e-02x0x0x0 + 9.223292e-03x0' = 0
#
# noise 10B, Trails: 29
# x0'' + 1.044746e+01x0 + 6.878231e-03x0x0x0x0x0 + 9.286158e-03x0' + -3.443517e-02x0x0'x0' = 0
#
# noise 10B, Trails: 30
# x0'' + 1.001217e+01x0 + 9.243348e-03x0' + 5.671453e-03x0x0'x0' = 0
#
# noise 10B, Trails: 31
# x0'' + 9.976459e+00x0 + 9.255872e-03x0' + 6.179276e-03x0x0'x0' = 0
#
# noise 10B, Trails: 32
# x0'' + 1.006640e+01x0 + 9.247637e-03x0' + 1.252134e-03x0x0'x0' + 3.545741e-04x0x0x0x0'x0' = 0
#
# noise 10B, Trails: 33
# x0'' + 9.881882e+00x0 + 3.317717e-02x0x0x0 + 9.257570e-03x0' = 0
#
# noise 10B, Trails: 34
# x0'' + 1.001903e+01x0 + 1.816839e-02x0x0x0 + 9.280325e-03x0' = 0
#
# noise 10B, Trails: 35
# x0'' + 1.018175e+01x0 + -1.751531e-02x0x0x0 + 9.296350e-03x0' + 7.582458e-04x0x0x0x0'x0' = 0
#
# noise 10B, Trails: 36
# x0'' + 9.898385e+00x0 + 3.201455e-02x0x0x0 + 9.267494e-03x0' = 0
#
# noise 10B, Trails: 37
# x0'' + 1.004760e+01x0 + -4.674359e-03x0x0x0 + 1.460315e-03x0x0x0x0x0 + 9.250575e-03x0' = 0
#
# noise 10B, Trails: 38
# x0'' + 9.865113e+00x0 + 9.215431e-03x0' + 1.025998e-02x0x0'x0' = 0
#
# noise 10B, Trails: 39
# x0'' + 9.972456e+00x0 + 9.281992e-03x0' + 6.581864e-03x0x0'x0' = 0
#
# noise 10B, Trails: 40
# x0'' + 9.745990e+00x0 + 1.191562e-01x0x0x0 + -5.495655e-03x0x0x0x0x0 + 9.201605e-03x0' = 0
#
# noise 10B, Trails: 41
# x0'' + 9.928642e+00x0 + 2.677893e-02x0x0x0 + 9.312263e-03x0' = 0
#
# noise 10B, Trails: 42
# x0'' + 1.037941e+01x0 + -2.413722e-02x0x0x0 + 9.234786e-03x0' = 0
#
# noise 10B, Trails: 43
# x0'' + 1.002812e+01x0 + 1.884455e-02x0x0x0 + 9.339199e-03x0' = 0
#
# noise 10B, Trails: 44
# x0'' + 1.026704e+01x0 + -6.091447e-02x0x0x0 + 4.105297e-03x0x0x0x0x0 + 9.284221e-03x0' = 0
#
# noise 10B, Trails: 45
# x0'' + 9.852944e+00x0 + 9.217064e-03x0' + 1.082148e-02x0x0'x0' = 0
#
# noise 10B, Trails: 46
# x0'' + 1.048256e+01x0 + 6.062782e-03x0x0x0x0x0 + 9.376359e-03x0' + -3.195783e-02x0x0'x0' = 0
#
# noise 10B, Trails: 47
# x0'' + 1.066822e+01x0 + 9.250401e-03x0' + -5.769362e-02x0x0'x0' + 5.476546e-03x0x0x0x0'x0' = 0
#
# noise 10B, Trails: 48
# x0'' + 1.003941e+01x0 + -1.482033e-02x0x0x0 + 9.299432e-03x0' + 1.102946e-03x0x0x0x0'x0' = 0
#
# noise 10B, Trails: 49
# x0'' + 9.822977e+00x0 + 3.838118e-02x0x0x0 + 9.297228e-03x0' = 0
#
# noise 10B, Trails: 50
# x0'' + 1.020803e+01x0 + -4.805445e-02x0x0x0 + 3.553787e-03x0x0x0x0x0 + 9.243313e-03x0' = 0
#
# noise 10B, Trails: 51
# x0'' + 1.079685e+01x0 + -2.084267e-01x0x0x0 + 9.225851e-03x0' + 5.560359e-03x0x0x0x0'x0' = 0
#
# noise 10B, Trails: 52
# x0'' + 1.032089e+01x0 + -8.501842e-02x0x0x0 + 5.479008e-03x0x0x0x0x0 + 9.273443e-03x0' = 0
#
# noise 10B, Trails: 53
# x0'' + 9.674276e+00x0 + -5.016035e-03x0x0x0x0x0 + 9.265897e-03x0' + 3.540418e-02x0x0'x0' = 0
#
# noise 10B, Trails: 54
# x0'' + 9.811995e+00x0 + 9.365034e-02x0x0x0 + 9.343416e-03x0' + -1.996247e-04x0x0'x0'x0'x0' = 0
#
# noise 10B, Trails: 55
# x0'' + 9.609969e+00x0 + 1.451036e-01x0x0x0 + -6.434342e-03x0x0x0x0x0 + 9.293134e-03x0' = 0
#
# noise 10B, Trails: 56
# x0'' + 1.019707e+01x0 + 2.644877e-03x0x0x0x0x0 + 9.226971e-03x0' + -1.016756e-02x0x0'x0' = 0
#
# noise 10B, Trails: 57
# x0'' + 1.017746e+01x0 + 3.406410e-03x0x0x0x0x0 + 9.288161e-03x0' + -1.277437e-02x0x0'x0' = 0
#
# noise 10B, Trails: 58
# x0'' + 1.000800e+01x0 + 9.176621e-03x0' + 5.770818e-03x0x0'x0' = 0
#
# noise 10B, Trails: 59
# x0'' + 9.963543e+00x0 + 2.498091e-02x0x0x0 + 9.276450e-03x0' = 0
#
# noise 10B, Trails: 60
# x0'' + 1.030623e+01x0 + -7.809329e-02x0x0x0 + 5.064620e-03x0x0x0x0x0 + 9.230046e-03x0' = 0
#
# noise 10B, Trails: 61
# x0'' + 9.816543e+00x0 + 8.979703e-02x0x0x0 + -3.815533e-03x0x0x0x0x0 + 9.290263e-03x0' = 0
#
# noise 10B, Trails: 62
# x0'' + 1.024910e+01x0 + 3.542521e-03x0x0x0x0x0 + 9.179446e-03x0' + -1.535878e-02x0x0'x0' = 0
#
# noise 10B, Trails: 63
# x0'' + 1.017840e+01x0 + 1.897933e-03x0x0x0x0x0 + 9.264184e-03x0' + -6.609081e-03x0x0'x0' = 0
#
# noise 10B, Trails: 64
# x0'' + 1.023964e+01x0 + 4.287260e-03x0x0x0x0x0 + 9.194241e-03x0' + -1.824878e-02x0x0'x0' = 0
#
# noise 10B, Trails: 65
# x0'' + 9.782234e+00x0 + -3.448171e-03x0x0x0x0x0 + 9.203324e-03x0' + 2.604498e-02x0x0'x0' = 0
#
# noise 10B, Trails: 66
# x0'' + 9.969676e+00x0 + 9.261337e-03x0' + 7.048140e-03x0x0'x0' = 0
#
# noise 10B, Trails: 67
# x0'' + 1.044436e+01x0 + 9.295989e-03x0' + -3.562496e-02x0x0'x0' + 3.524035e-04x0x0'x0'x0'x0' = 0
#
# noise 10B, Trails: 68
# x0'' + 1.010086e+01x0 + -2.412194e-02x0x0x0 + 9.259522e-03x0' + 1.222250e-04x0x0'x0'x0'x0' = 0
#
# noise 10B, Trails: 69
# x0'' + 1.024898e+01x0 + -5.481102e-02x0x0x0 + 3.769735e-03x0x0x0x0x0 + 9.211490e-03x0' = 0
#
# noise 10B, Trails: 70
# x0'' + 9.986882e+00x0 + 2.061610e-02x0x0x0 + 9.321756e-03x0' = 0
#
# noise 10B, Trails: 71
# x0'' + 1.001245e+01x0 + 9.270257e-03x0' + 5.446054e-03x0x0'x0' = 0
#
# noise 10B, Trails: 72
# x0'' + 1.066360e+01x0 + 9.171660e-03x0x0x0x0x0 + 9.242441e-03x0' + -4.964909e-02x0x0'x0' = 0
#
# noise 10B, Trails: 73
# x0'' + 1.030439e+01x0 + -6.349034e-02x0x0x0 + 9.196092e-03x0' + 2.013762e-03x0x0x0x0'x0' = 0
#
# noise 10B, Trails: 74
# x0'' + 1.020101e+01x0 + -4.105147e-02x0x0x0 + 3.088699e-03x0x0x0x0x0 + 9.269561e-03x0' = 0
#
# noise 10B, Trails: 75
# x0'' + 1.058447e+01x0 + -1.556730e-01x0x0x0 + 8.860931e-03x0x0x0x0x0 + 9.222974e-03x0' = 0
#
# noise 10B, Trails: 76
# x0'' + 1.004083e+01x0 + 1.162633e-03x0x0x0x0x0 + 9.214197e-03x0' = 0
#
# noise 10B, Trails: 77
# x0'' + 1.021242e+01x0 + -4.776938e-02x0x0x0 + 3.486624e-03x0x0x0x0x0 + 9.318334e-03x0' = 0
#
# noise 10B, Trails: 78
# x0'' + 9.680108e+00x0 + -5.145964e-03x0x0x0x0x0 + 9.200939e-03x0' + 3.574385e-02x0x0'x0' = 0
#
# noise 10B, Trails: 79
# x0'' + 1.010086e+01x0 + 9.219660e-03x0' + -7.399693e-03x0x0'x0' + 1.270004e-03x0x0x0x0'x0' = 0
#
# noise 10B, Trails: 80
# x0'' + 9.691621e+00x0 + 1.391458e-01x0x0x0 + 9.338173e-03x0' + -3.230081e-03x0x0x0x0'x0' = 0
#
# noise 10B, Trails: 81
# x0'' + 9.819327e+00x0 + 4.001611e-02x0x0x0 + 9.218174e-03x0' = 0
#
# noise 10B, Trails: 82
# x0'' + 9.978889e+00x0 + 2.203091e-02x0x0x0 + 9.301453e-03x0' = 0
#
# noise 10B, Trails: 83
# x0'' + 9.750912e+00x0 + 9.909584e-02x0x0x0 + -4.065716e-03x0x0x0x0x0 + 9.140097e-03x0' = 0
#
# noise 10B, Trails: 84
# x0'' + 1.029865e+01x0 + -7.602499e-02x0x0x0 + 9.313036e-03x0' + 2.443175e-03x0x0x0x0'x0' = 0
#
# noise 10B, Trails: 85
# x0'' + 9.889000e+00x0 + -2.603886e-03x0x0x0x0x0 + 9.260735e-03x0' + 1.969260e-02x0x0'x0' = 0
#
# noise 10B, Trails: 86
# x0'' + 9.815408e+00x0 + 9.035765e-02x0x0x0 + -3.863251e-03x0x0x0x0x0 + 9.225581e-03x0' = 0
#
# noise 10B, Trails: 87
# x0'' + 1.031618e+01x0 + -8.383884e-02x0x0x0 + 9.253910e-03x0' + 2.646120e-04x0x0'x0'x0'x0' = 0
#
# noise 10B, Trails: 88
# x0'' + 9.661480e+00x0 + 9.335667e-03x0' + 3.487887e-02x0x0'x0' + -2.351311e-04x0x0'x0'x0'x0' = 0
